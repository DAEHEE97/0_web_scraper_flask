# %% [markdown]
# # Python으로 웹 스크래퍼 만들기 2
#
# 사이트 운영자들은 웹 스크래핑 매우 싫어한다.
#
# 그래서 봇 인증 프로그램 등을 만들어 작업을 까다롭게 조치를 해두는 경우가 있다. ( 이용약관에도 기입해 두기도 한다. )
#
# 민감한 사항이 때문에 스크래핑한 내용을 상업적으로 사용할 경우 법적다툼이 벌어질 가능성도 있다.
#
# 교육 목적 이외에 상업적인 서비스를 만들 생각이라면 참고하자.

# %% [markdown]
# - URL Formatting
#
# - Requests
#
# - [HTTP Status Codes](https://developer.mozilla.org/ko/docs/Web/HTTP/Status)
#
# - dictionary
#
# - .startswith
#
# - f"{}"
#
# - find_all : list
#
# - find : v

# %% [markdown]
# ---

# %% [markdown]
# ## ~ 5.9

# %%
from requests import get 

from bs4 import BeautifulSoup


base_url = "https://weworkremotely.com/remote-jobs/search?utf8=✓&term="

search_term = "java"

response = get(f"{base_url}{search_term}")

    
if response.status_code != 200:
    print("Can't request website")
else:
    soup = BeautifulSoup(response.text,"html.parser")
    
    # print(soup.find_all('title'))

    jobs = soup.find_all('section', class_="jobs")
    # print(soup.find_all('section', class_="jobs"))    
    # print(len(jobs))
    
    results = []
    
    for job_section in jobs:
    
        # print(job_section.find_all('li')) 
        job_posts = job_section.find_all('li')
        
        # 리스트 컴프리헨션으로 view-all 클래스 제외 (버튼)
        job_posts = [post for post in job_section.find_all('li') if 'view-all' not in post['class']]

        for post in job_posts:
            
            
            anchors = post.find_all('a') # list
            
            anchor = anchors[1] # dictionary in list
            
            link = anchor['href'] # value in dictionary
            
            # anchor('a') 내 span tag (class = company)추출, list
            company, position, region = anchor.find_all('span',class_='company')
            
            title = anchor.find('span', class_='title')
            
            # html tag 제외 후, dictionary 데이터 생성 후, list append
            data_result = {
                'title': title.string,
                'company' : company.string,
                'position' : position.string,
                'region' : region.string,
                'link' : f'https://weworkremotely.com{link}'
                }
            
            results.append(data_result)
        
    
    for result in results:
        print(result)

# %% [markdown]
# ---

# %% [markdown]
# ## Refactoring
#
# - search_term 을 parameter 로 받고, dict 데이터로 results 를 return 하는 함수 생성

# %%
from requests import get 
from bs4 import BeautifulSoup

# extract 폴더, wwr.py 파일, extract_jobs 함수 import

from extract.wwr import extract_jobs

jobs = extract_jobs('python')
print(jobs)

# %% [markdown]
# ---

# %% [markdown]
# ## Request 응답 거절
#
# - Request로 접속, response code : 403
#
#
# - 403 Forbidden
#
# 클라이언트는 콘텐츠에 접근할 권리를 가지고 있지 않습니다.
#
# 예를들어 그들은 미승인이어서 서버는 거절을 위한 적절한 응답을 보냅니다. 401과 다른 점은 서버가 클라이언트가 누구인지 알고 있습니다.

# %%
from requests import get
from bs4 import BeautifulSoup


base_url = "https://kr.indeed.com/jobs?q="
search_term = "python"

response = get(f"{base_url}{search_term}")

if response.status_code != 200:
    print("Cant request website")
else:
    print(response.text)

# %%
print(response.status_code)

# %% [markdown]
# ---

# %% [markdown]
# ## Selenium
#
# - https://www.selenium.dev/
#
# - requests get 으로 403 forbidden, Selenium 을 이용하여 해결
# ---
#
# BeautifulSoup 한계
#
# 바로, "자바스크립트로 동적으로 생성된 정보는 가져올 수 없다!"입니다.
#
# 자바스크립트가 발전을 하면서, Ajax(비동기 통신) 형태로 서버와 데이터를 주고 받아 화면에 뿌려주는 사이트가 많아 졌습니다.
#
# 이러한 형식으로 데이터를 주고 받으면 url 변경이나 새로고침 없이 데이터를 가져오게 됩니다.
#
# 아마도 스크래핑을 시도하다가 데이터를 가져와야 정상인데, 아무것도 가져오지 못하는 현상을 마주친적이 있을 거에요.
#
# 대부분의 경우가 자바스크립트로 HTML을 만들어서 그렇습니다.
#
# Selenium 라이브러리를 사용하는 이유는 다음과 같습니다.
#
#     1. 자바스크립트가 동적으로 만든 데이터를 크롤링 하기 위해
#
#     2. 사이트의 다양한 HTML 요소에 클릭, 키보드 입력 등 이벤트를 주기 위해
#
# Selenium을 잘 활용하면, 평소에 반복적으로 하고 있는 웹상의 업무를 자동화할 수도 있습니다.
#
#     1. 자동으로 로그인하기
#
#     2. 메일보내기 자동화
#
#     3. 블로그 이웃새글 자동좋아요 누르기
#
#     4. 인스타그램 자동으로 좋아요, 댓글 작성하기
#
#     5. 등등 정말 많은 다양한 일

# %%
# indeed 403 fix

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

# for Replit option

# options.add_argument("--no-sandbox")
# options.add_argument("--disable-dev-shm-usage")

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

# response = get(f"{base_url}{search_term}")
browser.get(f"{base_url}?q={search_term}")

print(browser.page_source)

# %%
type(browser)

# %% [markdown]
# ---

# %% [markdown]
# <img src = '2.png' height ='500' width = '500'>

# %% [markdown]
# ## Recursive
#
#
# 1. find 로 `ul` 찾음
#
#
# 2. find_all 로 `ul` 안에 li 모두 찾음 (li 안에 li)
#
#
# - `ul` 바로 안에 `li` 만을 찾길 원함.
# -  `li` 안에 `li` 제외
# - 1 level 만 들어감 깊게 들어가는거 방지

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

browser.get(f"{base_url}?q={search_term}")

# --- bs4 처리 

soup = BeautifulSoup(browser.page_source, "html.parser")

job_list = soup.find("ul", class_="jobsearch-ResultsList")

jobs = job_list.find_all('li', recursive=False)

print(len(jobs))
print()

for job in jobs:
    print(job)

# %% [markdown]
# ---

# %% [markdown]
# ## None
#
# - 무언가 '없읍'
#
# - false 랑 다름
#
# - html 데이터 -> ul -> li (recursive=False)
#
# - 이 후 필터링 으로 "div", class_="mosaic-zone" 데이터 처리

# %% [markdown]
# <img src = '3.png' height ='500' width = '500'>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

browser.get(f"{base_url}?q={search_term}")

# --- bs4 처리 

soup = BeautifulSoup(browser.page_source, "html.parser")

job_list = soup.find("ul", class_="jobsearch-ResultsList")

jobs = job_list.find_all('li', recursive=False)


# li 태그 중 class 네임에 따라 출력,
# find, none 논리로 출력 

for job in jobs:
    
    zone = job.find("div", class_="mosaic-zone")
    
    if zone == None:
        print("job li")
    else:
        print("mosaic li")

# %% [markdown]
# ---

# %% [markdown]
# ## Select
#
# - select_one > dict 형으로 한번에
#
# - find_all('') > 태그 를 리스트화
#
#
# - https://nomadcoders.co/python-for-beginners/lectures/3801

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

browser.get(f"{base_url}?q={search_term}")

# --- bs4 처리 

soup = BeautifulSoup(browser.page_source, "html.parser")

job_list = soup.find("ul", class_="jobsearch-ResultsList")

jobs = job_list.find_all('li', recursive=False)


# li 태그 중 class 네임에 따라 출력,
# find, none 논리로 출력 

results = []

for job in jobs:
    
    zone = job.find("div", class_="mosaic-zone")
    
    if zone == None:
        
        # anchor = job.find_all('a') # list

        anchor = job.select_one('h2 a') # dict
        
        title = anchor['aria-label']
        link = anchor['href']
        
        company = job.find('span', class_='companyName')
        location = job.find('div', class_='companyLocation')
    
        # dict 데이터 형
        job_data = {
            'position': title,
            'link': f"https://kr.indeed.com{link}",
            'company': company.string,
            'location': location.string
        }
        
        # 결과 리스트 append
        results.append(job_data)
    
    else:
        print("mosaic li")
    
for result in results:
    print(result)
    print()
# Out:
# mosaic li
# mosaic li
# mosaic li
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}

# %%
print(title)

# %%
print(link)

# %%
print(company)

# %%
print(location)

# %% [markdown]
# ---

# %% [markdown]
# ## pages
#
#
# - 페이지가 1개
#
# - 페이지가 여러개, 이동 버튼 없음
#
# - 페이지가 여러개, 이동 버튼 있음 (6개이상 존재)

# %% [markdown]
# 1. 태그랑, class 네임 둘다 변경 `nav`, `div`, `css-jbuxu0 ecydgvn0`
#
#
# 2. `pagination = soup.find('nav', class_='css-jbuxu0 ecydgvn0')`   시 일단 모두 생성됨. none 으로 return x 일단 생성 o
#
#
# 3. `pages = pagination.find_all('div', recursive=False)` 있으면 리스트화, 없으면 [] 빈 리스트
#     - <class 'bs4.element.ResultSet'>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options



def get_page_count(keyword):
    
    options = Options()
    browser = webdriver.Chrome(options=options)

    base_url = "https://kr.indeed.com/jobs"
    browser.get(f"{base_url}?q={keyword}")
    
    soup = BeautifulSoup(browser.page_source, "html.parser")
    
    pagination = soup.find('nav', class_='css-jbuxu0 ecydgvn0')    
    
    pages = pagination.find_all('div', recursive=False)
    length = len(pages)
    
    # 5를 초과하는 6 이상 부터는 처리 하지 않을 예정
    if length == 0:
        return 1
    elif length > 5:
        return 5
    else: 
        return length

# %%
get_page_count('react')
# Out:
# 5

# %%
get_page_count('nest')
# Out:
# 1

# %% [markdown]
# ## Refactoring - 2
#
# - 함수화
# - pages 추가

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options




def extract_indeed_jobs(keyword):
    
    pages = get_page_count(keyword)
    
    for page in range(pages):
        
        options = Options()

        browser = webdriver.Chrome(options=options)
        
        base_url = "https://kr.indeed.com/jobs"
        search_term = f'{keyword}'

        browser.get(f"{base_url}?q={search_term}")

        # --- bs4 처리 

        soup = BeautifulSoup(browser.page_source, "html.parser")

        job_list = soup.find("ul", class_="jobsearch-ResultsList")

        jobs = job_list.find_all('li', recursive=False)


        # li 태그 중 class 네임에 따라 출력,
        # find, none 논리로 출력 

        results = []

        for job in jobs:

            zone = job.find("div", class_="mosaic-zone")

            if zone == None:

                # anchor = job.find_all('a') # list

                anchor = job.select_one('h2 a') # dict

                title = anchor['aria-label']
                link = anchor['href']

                company = job.find('span', class_='companyName')
                location = job.find('div', class_='companyLocation')

                # dict 데이터 형
                job_data = {
                    'position': title,
                    'link': f"https://kr.indeed.com{link}",
                    'company': company.string,
                    'location': location.string
                }

                # 결과 리스트 append
                results.append(job_data)

        for result in results:
            print(result)
            print()

# %%
# 1번 페이지 5번 반복 

extract_indeed_jobs('python')
# Out:
# mosaic li
# mosaic li
# mosaic li
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# mosaic li
# mosaic li
# mosaic li
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': 'Application Engineer II의 전체 세부 정보', 'link': 'https://kr.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0C_VxUQDhzcEtU5UIQUIXNdycmbXVRtU8htuAzRK_ilEtj_GUc6UbOCUkMoh8528Fho-TRvpmXl2x7mqXskRWj-y0IUtWdxx1nWjWoZeZ4_wlR4mPCGjlet8c1Y6klaC079r7ACIQHXBYWGNmoWNTk2xLXXB4ZNZNSm_ApxVVKFYGgwjsTPRqj56GfyheU5K2Oj3hTxQlA-Z84L6rOtWCSC2R5RZabtXsDnHgYcpAPfm9DKRAdeBYu0QWwFCRtafdLCNQqfSEX3f2UWrgCnqsYelitgT34Fxx4OTUoLj1iR4sVf56Ht5o6cLkMF1sVfqnexUF1PMxvgQLDMK5bjEIjqUTFJLtkrMn2xW29YxmPDY2-blx9bW6-BrWvHm26-8VH-sHgaL9jIAsIe9U6KI9U3j0wb8c5Ufax_alFIkBOk3l1mhCCgagJzgEkgzkG8mM5Ewq7OGFpl9_DT2crA-5Iu2mDcX_FZSBEUmTf4XBg2Hd6Kzul3L1i41rZAjU9Ljte0IGZfqdbsT8NzQTBRgy7D51mMmUK76kvh1W-RBsMSPDyh6aW6ter75rSUuVDsx4USr4fxaRCwIPqvjFvJFo9sXdBpoVXupkKwMTIQA7s3-zmcNmL3FlPFyyXVdyt7tZH6NLMohlrL6H1ZbGo3yLePEfWnXh6klmHbgWt0MnKEQeLF-vSBPABuGOf9StGJzgcuLg-J9HbB7G3A5Np4F_V-FRxmQGDMYQ9FudbByRKCJ3uoDUkzk9kZ4f7h4188TFBWx-OjH_rRwAR415ZhrGkHgGiNYZFNXj4YTQ1RHV9Q1lnvAL2cZncmT6CQgXnlEiQSUMzkAzq1xNM_MFOzEKI9zUJnqhJNbKHoOapzUZrk_eVRKxOEiz5VwbNxItwW6BeWw_XujyevB-Qi2dOJaKvLnFKOWpNKzcgbhXu4ro9N3X4r00qCEWzYQEDCEUnU4xdil1ORPCQnFjxHnk_DXPu4B_v9YfiXs7BNZwtxn3lB_eTdAztgqd1nj2RzaPJlx4hRekm1_JA6DHIzGrRm14d35X8CXEkzWiWQYp6zJvZOgYTAfLE1Pv46g-R7ie2qMKA7l_dQIbcmqqLafQGV1pUiMYlvaiqsFLhyq1TPEfyuDm04fciYpFc13O4TfuOr81g=&xkcb=SoCG-_M3PKDRTdxYGR0DbzkdCdPP&p=8&fvj=0&vjs=3', 'company': 'Ansys', 'location': '서울'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# mosaic li
# mosaic li
# mosaic li
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
# mosaic li
# mosaic li
# mosaic li
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# mosaic li
# mosaic li
# mosaic li
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}

# %% [markdown]
# ---

# %% [markdown]
# `options = Options()`
# `browser = webdriver.Chrome(options=options)`
#
# 를 함수 내에서 실행시키게 해야함.
#
# - 켜져있는 상태로, 한번 더 켜지면, 봇 의심
#
# - 함수 내에서 오픈하게 되면, 실행 후, 꺼지고, 다시 실행
#
# - 오픈, 카운트, 클로즈
#
# - 1~5. 오픈, 출력, 클로즈

# %% [markdown]
# ---

# %% [markdown]
# ## Refactoring -3
#
# - 1 ~ 5 번페이지 start 처리
#
# - page 에 따라 start 부분 처리 x(0), 10, 20
#
# - start를 0처리 하면, start 없이 요청 하는것과 같은 결과가 나옴
#
# - result 빼서 처리

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


def extract_indeed_jobs(keyword):
    
    pages = get_page_count(keyword)
    
    results = []
  
    for page in range(pages):
        
        options = Options()

        browser = webdriver.Chrome(options=options)
        
        base_url = "https://kr.indeed.com/jobs"
        search_term = f'{keyword}'

        browser.get(f"{base_url}?q={search_term}&start={page*10}")

        # --- bs4 처리 

        soup = BeautifulSoup(browser.page_source, "html.parser")

        job_list = soup.find("ul", class_="jobsearch-ResultsList")

        jobs = job_list.find_all('li', recursive=False)


        # li 태그 중 class 네임에 따라 출력,
        # find, none 논리로 출력 


        for job in jobs:

            zone = job.find("div", class_="mosaic-zone")

            if zone == None:

                # anchor = job.find_all('a') # list

                anchor = job.select_one('h2 a') # dict

                title = anchor['aria-label']
                link = anchor['href']

                company = job.find('span', class_='companyName')
                location = job.find('div', class_='companyLocation')

                # dict 데이터 형
                job_data = {
                    'position': title,
                    'link': f"https://kr.indeed.com{link}",
                    'company': company.string,
                    'location': location.string
                }

                # 결과 리스트 append
                results.append(job_data)

    
    for result in results:
        print(result)
        print()

# %%
extract_indeed_jobs('python')
# Out:
# {'position': 'Financial, Regulatory and Risk Reporting Speciallist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e842304541b3a53&fccid=f1d8e147024abb3f&vjs=3', 'company': 'Deutsche Bank', 'location': '서울'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Python Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2fc2142a72a2007&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': 'Cloud기반 Data Platform Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8898ea01db8636e&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '[전문연구요원] 의료영상 리서치 엔지니어 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3544467a7b64376f&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 마포구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': 'Intern - Development Cooperation Team (2 Positions)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1e1544f6de47cf48&fccid=a9a8bf2e786e3726&vjs=3', 'company': 'United Nations Development Programme (UNDP)', 'location': '서울'}
#
# {'position': 'Data Scientist in Financial의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8384fbc0b8152ec6&fccid=071ef5e261747b4b&vjs=3', 'company': '페니로이스', 'location': '서울 종로구'}
#
# {'position': '[KITRI] IT 정보 보안/개발 교육생의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8274c2d094ef24ac&fccid=f065bd051552743e&vjs=3', 'company': '한국정보기술연구원', 'location': '서울'}
#
# {'position': '백엔드 개발자(인턴십)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b7223c792bfcbcd4&fccid=5013eca338141e7d&vjs=3', 'company': '액스', 'location': '서울 서초구'}
#
# {'position': '[HYBE] ITSM/CS의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=82477cde004f6386&fccid=55c46c15186153ee&vjs=3', 'company': '하이브', 'location': '서울 용산구'}
#
# {'position': '파이썬(python) 백엔드 개발자 (전문연구요원 가능)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=240326a26bd13bf2&fccid=660bbb21789ab63d&vjs=3', 'company': '아토머스', 'location': '서울 강남구'}
#
# {'position': 'Boeing Korea Summer Intern_Software Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=9261f808b885e89a&fccid=edae4285faf6c2f0&vjs=3', 'company': 'BOEING', 'location': '서울'}
#
# {'position': 'Analytics Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/company/%EB%A7%88%EC%BC%93%ED%95%8F%EB%9E%A9/jobs/Analytics-Engineer-643e1ff49cc2cc0e?fccid=3f1bbd0e33a2be0c&vjs=3', 'company': '마켓핏랩', 'location': '서울'}
#
# {'position': '[2023 Summer Internship] MedTech – Strategic Commercial Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2926e817928cf0c5&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '데이터분석 신입/경력 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=88960e11c2cdd682&fccid=72348558bd9456ba&vjs=3', 'company': '블록스퀘어서울', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech - Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=fedd89e18af95c50&fccid=dd564dec75d08f91&vjs=3', 'company': '한국존슨앤드존슨메디칼', 'location': '서울 용산구'}
#
# {'position': 'IT사업 부문별 경력사원 (사업 확장에 따른 인재 )의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=91b5ee6bdae33956&fccid=62d06d841710893c&vjs=3', 'company': '교보정보통신', 'location': '서울 종로구'}
#
# {'position': '양자화학/MD시뮬레이션 분야 연턴 *조기마감 가능의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=47281e8d9a288722&fccid=056b41d707659c93&vjs=3', 'company': '에스케이스페셜티', 'location': '서울'}
#
# {'position': '상시지원 (AI & ML Engineer)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=14a95a5daad2295e&fccid=933989f3b0ffe928&vjs=3', 'company': 'Riiid Labs', 'location': '서울'}
#
# {'position': '[데브시스터즈] Data Analyst의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=6b53335986238646&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': '[코어라인소프트] 3D 솔루션 개발자 찾습니다.의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8abb8479693ab966&fccid=af283ee927a56dfc&vjs=3', 'company': '코어라인소프트', 'location': '서울 마포구'}
#
# {'position': '디지털 자산 리서치 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a5b4dfb90415269e&fccid=54c9c086b03b7cdc&vjs=3', 'company': 'Dunamu', 'location': '서울'}
#
# {'position': 'AI R&D (Research and Development) Engineer (전문연구요원 가능)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=56d3950c0672dfe1&fccid=1c5712d7c48c7685&vjs=3', 'company': '이마고웍스', 'location': '서울 강남구'}
#
# {'position': '계량투자(AI Quant) 연구원(석사이상) 경력자 모집의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=%5B%ED%97%A4%EB%93%9C%ED%97%8C%ED%8C%85%5D-%EA%B5%AD%EB%82%B4%EC%9C%A0%EB%AA%85%EB%8C%80%EA%B8%B0%EC%97%85&ti=%EA%B3%84%EB%9F%89%ED%88%AC%EC%9E%90%28ai+Quant%29+%EC%97%B0&jk=799d372768094b3c&fccid=6b77749dbefab4c1&vjs=3', 'company': '대기업 연구소', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '개발자 - 유니티 /풀스택 /3D 클라이언트 부문의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=878cb0fffc57721c&fccid=dd616958bd9ddc12&vjs=3', 'company': '슬래쉬', 'location': '서울 마포구'}
#
# {'position': 'Data Scientist(데이터 사이언티스트)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=54e4b7a9a2c255f1&fccid=c44bf11dec3a719d&vjs=3', 'company': '인포카', 'location': '서울 성북구'}
#
# {'position': '데이터표준품질부문 경력직 (정규직)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2dab915188811f21&fccid=99925e8e7b9604cc&vjs=3', 'company': '한국정보기술단', 'location': '서울 강남구'}
#
# {'position': 'Python_Backend Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=272637ad170fe32c&fccid=54c9c086b03b7cdc&vjs=3', 'company': 'Dunamu', 'location': '서울'}
#
# {'position': 'Machine Learning Engineer Intern - Korea의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=69d3cc2cca262747&fccid=6588d205440cdcb9&vjs=3', 'company': 'MOLOCO', 'location': '서울'}
#
# {'position': '[대기업] 데이터분석가 경력 (대리~과장급 2명)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b2eb1fe78ff9ee5f&fccid=b8c1027d6dda0525&vjs=3', 'company': '에이치알니즈', 'location': '서울'}
#
# {'position': 'AI 연구개발자 전문연구요원(병역특례)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=328f9e7ab47f7ff1&fccid=e391d8e930358bac&vjs=3', 'company': '라이트비전', 'location': '서울 성동구'}
#
# {'position': '(CV) 딥러닝 알고리즘 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5c9f5abee32825e9&fccid=aba88c202493b8a5&vjs=3', 'company': '메디픽셀', 'location': '서울 강남구'}
#
# {'position': '[AI팀] 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=16558338d5ad9bb2&fccid=94a6c170510fa77e&vjs=3', 'company': '에프앤가이드', 'location': '서울 영등포구'}
#
# {'position': '[신입] 미래 인재 DB의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8488f46665d1b77a&fccid=d5a22a3e93377742&vjs=3', 'company': '현대오토에버', 'location': '서울'}
#
# {'position': '[금융SM] 그룹공동 마이데이터 분석플랫폼(수집적재/분석모델) Tech 경력 정규의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=6f6c89b643f60328&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': 'Staff, Data Scientist (S&OP)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=533f6ee06084f86f&fccid=56e12959d04ef145&vjs=3', 'company': 'Coupang', 'location': '서울'}
#
# {'position': 'SW Engineer Intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=87862422e27c1249&fccid=936367796261bd6e&vjs=3', 'company': 'INTEL', 'location': '서울'}
#
# {'position': '인공지능(AI), 머신러닝(ML) 외 경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=6dab9c1fdc2c4374&fccid=b48377719ace2e16&vjs=3', 'company': '쉬모스랩', 'location': '서울 강남구'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '국내 대기업 - 고객 데이터분석 포지션의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=75c348600e4ba140&fccid=28f5722fca6f5b12&vjs=3', 'company': '라피플코리아리미티드', 'location': '서울'}
#
# {'position': 'OpenCV/MATLAB/TensorFlow/Python/C/C++/Linux 알고리즘 엔지니어의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a07e312c73864b17&fccid=f401a9b533c97602&vjs=3', 'company': '더마미러', 'location': '서울 서초구'}
#
# {'position': '디지털쇼룸 구축/운영 부문 경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bca4d5531a17ab9d&fccid=d5a22a3e93377742&vjs=3', 'company': '현대오토에버', 'location': '서울 강남구'}
#
# {'position': 'Database Administrator (DBA), Amazon Games의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e38403ef07d5c777&fccid=fe2d21eef233e94a&vjs=3', 'company': 'Amazon Services Korea LLC', 'location': '서울'}
#
# {'position': 'Data Scientist, Growth Analytics Intern - Korea의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3d0e22b9756facb8&fccid=6588d205440cdcb9&vjs=3', 'company': 'MOLOCO', 'location': '서울'}
#
# {'position': '(주)한화 전략부문 (주)한화/전략부문 Data Engineer 채용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=fb243a05e63349df&fccid=bd0dc1817223394f&vjs=3', 'company': '한화그룹', 'location': '서울'}
#
# {'position': '[카트라이더: 드리프트] 머신러닝 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5195ea166a5b9b30&fccid=3343bd3ef4658848&vjs=3', 'company': '니트로스튜디오', 'location': '서울 강남구'}
#
# {'position': 'Data/Machine Learning Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5ab0b45dfa93411b&fccid=01aed038bcce2a5f&vjs=3', 'company': '플리토', 'location': '서울 강남구'}
#
# {'position': 'Data Scientist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=9cb8324539546a71&fccid=18c4935c8ec646d5&vjs=3', 'company': 'Toss', 'location': '서울'}
#
# {'position': 'Application Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3e5a9dc2a01a89f2&fccid=a8128b0f1af14ed3&vjs=3', 'company': 'AVL', 'location': '서울'}
#
# {'position': 'SQL, Python 기반 Data Engineer(경력직) 채용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1720b452301b54aa&fccid=4c458be029af0a85&vjs=3', 'company': '파인트리파트너스 주식회사 관심기업', 'location': '서울 도화동'}
#
# {'position': 'Conversational AI Implementation Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ad6564786cb10cbd&fccid=6e36b32060404d12&vjs=3', 'company': '마인드에이아이', 'location': '서울 중구'}
#
# {'position': '디지털마케팅 컨설턴트(5명 이상, 경력 2년~15년) , S그룹 경영컨설팅회사(서울 잠실역 근처)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e106e21750a41abd&fccid=a71819ff34fb2d90&vjs=3', 'company': '코어포인트', 'location': '서울'}
#
# {'position': 'Software Engineer - Python and K8s의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=9e154b5b00d09b31&fccid=3911cf63fc0692f4&vjs=3', 'company': 'Canonical - Jobs', 'location': '서울'}
#
# {'position': '국내 대기업 계열사 - 마케팅 데이터분석 및 CRM 담당자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=384938caaf89c494&fccid=28f5722fca6f5b12&vjs=3', 'company': '라피플코리아리미티드', 'location': '서울'}
#
# {'position': '[KR] Solutions Engineer, TikTok Ads의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e859aef236922ced&fccid=caed318a9335aac0&vjs=3', 'company': 'TikTok', 'location': '서울'}
#
# {'position': '2023년 상시 [신입/경력] 개발자 중의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5939f1161708ca93&fccid=0673ca84bc014599&vjs=3', 'company': '사이냅소프트', 'location': '서울 강서구'}
#
# {'position': 'Payment Technology - IT Administrator - Fixed Term Contract - Veteran Program의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=fa37854cf78da18b&fccid=c46d0116f6e69eae&vjs=3', 'company': 'JPMorgan Chase Bank, N.A.', 'location': '서울'}
#
# {'position': '[AI/Lab] 머신러닝 리서치 엔지니어 (전문연구요원 가능)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=0a95c840f82cb01e&fccid=d18b6eed9577092f&vjs=3', 'company': '버즈니', 'location': '서울'}
#
# {'position': '[K디지털 트레이닝] 전액 국비지원 IT취업연계 교육 빅데이터, 인공지능의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8eb2784e62502c5f&fccid=2f25bb139639ef63&vjs=3', 'company': '중앙정보처리학원', 'location': '서울 마포구'}
#
# {'position': '데이터 개발자 및 빅데이터 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=277b1479621c4dcc&fccid=7d08c55041404b21&vjs=3', 'company': '애크미랩', 'location': '서울 강남구'}
#
# {'position': 'Full-Stack Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=7fa613689887579f&fccid=edae4285faf6c2f0&vjs=3', 'company': 'BOEING', 'location': '서울'}
#
# {'position': '[레드테이블] 데이터 엔지니어 / 데이터 마케터 (정규직)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=778999d4fe8080ec&fccid=ace798f3c93e0fc7&vjs=3', 'company': '레드테이블', 'location': '서울 중구'}
#
# {'position': 'Python 분석 인원 정규직 채용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5e761f105a377ae8&fccid=307824036b9dcb17&vjs=3', 'company': '(주)스마트모빌러티 관심기업', 'location': '서울 휘경동'}

# %% [markdown]
# ---

# %% [markdown]
# - 완전 함수로 변환
#
# - return 리스트

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


def extract_indeed_jobs(keyword):
    
    pages = get_page_count(keyword)
    
    results = []
  
    for page in range(pages):
        
        options = Options()

        browser = webdriver.Chrome(options=options)
        
        base_url = "https://kr.indeed.com/jobs"
        search_term = f'{keyword}'
        final_url = f"{base_url}?q={search_term}&start={page*10}"
        
        print(f'Request url : {final_url}')
        browser.get(final_url)

        # --- bs4 처리 

        soup = BeautifulSoup(browser.page_source, "html.parser")

        job_list = soup.find("ul", class_="jobsearch-ResultsList")

        jobs = job_list.find_all('li', recursive=False)


        # li 태그 중 class 네임에 따라 출력,
        # find, none 논리로 출력 


        for job in jobs:

            zone = job.find("div", class_="mosaic-zone")

            if zone == None:

                # anchor = job.find_all('a') # list

                anchor = job.select_one('h2 a') # dict

                title = anchor['aria-label']
                link = anchor['href']

                company = job.find('span', class_='companyName')
                location = job.find('div', class_='companyLocation')

                # dict 데이터 형
                job_data = {
                    'position': title,
                    'link': f"https://kr.indeed.com{link}",
                    'company': company.string,
                    'location': location.string
                }

                # 결과 리스트 append
                results.append(job_data)

    
    return results

# %%
jobs = extract_indeed_jobs('python')
print(jobs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 jobs = extract_indeed_jobs('python')
#       2 print(jobs)
#
# Cell In[1], line 8, in extract_indeed_jobs(keyword)
#       6 def extract_indeed_jobs(keyword):
# ----> 8     pages = get_page_count(keyword)
#      10     results = []
#      12     for page in range(pages):
#
# NameError: name 'get_page_count' is not defined

# %%
print(len(jobs))
# Out:
# 75

# %% [markdown]
# - 첫번째 페이지로 이동후, 그 이후 페이지가 몇개 있는지 확인, 제약사항(5) 후 처리
