# %% [markdown]
# # Python으로 웹 스크래퍼 만들기 2
#
# 사이트 운영자들은 웹 스크래핑 매우 싫어한다.
#
# 그래서 봇 인증 프로그램 등을 만들어 작업을 까다롭게 조치를 해두는 경우가 있다. ( 이용약관에도 기입해 두기도 한다. )
#
# 민감한 사항이 때문에 스크래핑한 내용을 상업적으로 사용할 경우 법적다툼이 벌어질 가능성도 있다.
#
# 교육 목적 이외에 상업적인 서비스를 만들 생각이라면 참고하자.

# %% [markdown]
# ---

# %% [markdown]
# - URL Formatting
#
# - Requests
#
# - [HTTP Status Codes](https://developer.mozilla.org/ko/docs/Web/HTTP/Status)
#
# - dictionary
#
# - .startswith
#
# - f"{}"
#
# - find_all : list
#
# - find : v

# %% [markdown]
# ---

# %% [markdown]
# ## Refactoring
#
# - search_term 을 parameter 로 받고, dict 데이터로 results 를 return 하는 함수 생성

# %%
from requests import get 
from bs4 import BeautifulSoup

# extract 폴더, wwr.py 파일, extract_jobs 함수 import

from extract.wwr import extract_jobs

jobs = extract_jobs('python')

print(jobs)

print(len(jobs))
# Out:
# [{'position': 'Full-Time', 'company': 'OpenCraft', 'location': 'Anywhere in the World', 'link': 'https://weworkremotely.com/remote-jobs/opencraft-senior-open-source-developer-devops-python-django-react-aws-openstack'}, {'position': 'Full-Time', 'company': 'Close', 'location': 'USA Only', 'link': 'https://weworkremotely.com/remote-jobs/close-senior-staff-software-engineer-backend-python-usa-100-remote'}, {'position': 'Full-Time', 'company': 'Proxify AB', 'location': 'Latin America Only/Europe Only/EMEA Only', 'link': 'https://weworkremotely.com/remote-jobs/proxify-ab-senior-backend-python-engineer-long-term-job-100-remote'}]
# 3

# %% [markdown]
# ---

# %% [markdown]
# ## Request 응답 거절
#
# - Request로 접속, response code : 403
#
#
# - 403 Forbidden
#
# 클라이언트는 콘텐츠에 접근할 권리를 가지고 있지 않습니다.
#
# 예를들어 그들은 미승인이어서 서버는 거절을 위한 적절한 응답을 보냅니다. 401과 다른 점은 서버가 클라이언트가 누구인지 알고 있습니다.

# %%
from requests import get
from bs4 import BeautifulSoup

base_url = "https://kr.indeed.com/jobs?q="
search_term = "python"

response = get(f"{base_url}{search_term}")

if response.status_code != 200:
    print("Can't request website")
else:
    print(response.text)
# Out:
# Can't request website

# %%
print(response.status_code)
# Out:
# 403

# %% [markdown]
# ---

# %% [markdown]
# ## Selenium
#
# - https://www.selenium.dev/
#
# - requests get 으로 403 forbidden, Selenium 을 이용하여 해결
# ---
#
# BeautifulSoup 한계
#
# 바로, "자바스크립트로 동적으로 생성된 정보는 가져올 수 없다!"입니다.
#
# 자바스크립트가 발전을 하면서, Ajax(비동기 통신) 형태로 서버와 데이터를 주고 받아 화면에 뿌려주는 사이트가 많아 졌습니다.
#
# 이러한 형식으로 데이터를 주고 받으면 url 변경이나 새로고침 없이 데이터를 가져오게 됩니다.
#
# 아마도 스크래핑을 시도하다가 데이터를 가져와야 정상인데, 아무것도 가져오지 못하는 현상을 마주친적이 있을 거에요.
#
# 대부분의 경우가 자바스크립트로 HTML을 만들어서 그렇습니다.
#
# Selenium 라이브러리를 사용하는 이유는 다음과 같습니다.
#
#     1. 자바스크립트가 동적으로 만든 데이터를 크롤링 하기 위해
#
#     2. 사이트의 다양한 HTML 요소에 클릭, 키보드 입력 등 이벤트를 주기 위해
#
# Selenium을 잘 활용하면, 평소에 반복적으로 하고 있는 웹상의 업무를 자동화할 수도 있습니다.

# %% [markdown]
# ---

# %%
# indeed 403 fix

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

# for Replit option

# options.add_argument("--no-sandbox")
# options.add_argument("--disable-dev-shm-usage")

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

# response = get(f"{base_url}{search_term}")

browser.get(f"{base_url}?q={search_term}")

print(browser.page_source) # html source code 추출
# Out:
# <html dir="ltr" lang="ko" class="js-focus-visible" data-js-focus-visible=""><head>
#     <link rel="shortcut icon" href="/images/favicon.ico">
#     <title>2023년 5월 24일 Python 취업, 일자리, 채용 | Indeed.com</title>
#     <meta http-equiv="content-type" content="text/html; charset=utf-8">
#     <meta name="description" content="[2023 Summer Internship] Medtech – Business Excellence, 관리 프로그램 개발자, 인턴 외에도 848 건 이상의 Python 관련 일자리가 Indeed.com에 있습니다!">
#     <meta name="keywords" content="Python 취업, 채용정보,  careers,  employment,  job listings,  job search,  search engine, work in ">
#     <meta name="referrer" content="origin-when-cross-origin">
#     <link rel="canonical" href="https://kr.indeed.com/q-python-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">
#     <link rel="alternate" href="android-app://com.indeed.android.jobsearch/https/kr.indeed.com/m/jobs?q=python">
#     <link rel="alternate" href="ios-app://https/kr.indeed.com/m/jobs?q=python">
#     <link rel="alternate" type="application/rss+xml" title="Python 취업, 채용정보" href="https://kr.indeed.com/rss?q=python">
#     <meta name="viewport" content="width=device-width,initial-scale=1.0">
#         <meta name="format-detection" content="telephone=no">
#
#     <style>
#         html body *, html body div .gnav * { font-family: 'Noto Sans', 'Helvetica Neue', Helvetica, Arial, sans-serif !important; }
#     </style>
#
#     <link rel="stylesheet" href="//d3fw5vlhllyvee.cloudfront.net/m/s/7f91053a903dbbd55938/styles/serpGlobal.css">
#     <script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script id="mobile-shared-dep-modules">
#                 window._INDEED = window._INDEED || {};
#                 window._INDEED.modules = [{"container":"mobileSharedDeps","module":".\u002FSerpGlobal","shareScope":"react17","urls":["\u002F\u002Fd3fw5vlhllyvee.cloudfront.net\u002Fm\u002Fs\u002Fscripts\u002Freact17\u002FmobileSharedDeps.remoteEntry.0ef8d87a1f2900a0f0fb.js"]}];
#                 window.addEventListener("DOMContentLoaded",()=>{window._INDEED&&window._INDEED.modules&&window._INDEED.modules.forEach(d=>{var e=()=>{window._INDEED.shared.v1.load("module",d)};window._INDEED&&window._INDEED.shared&&window._INDEED.shared.v1?e():window.addEventListener("onSharedDepsLoadersV1Available",e,{once:!0})})});</script>
#             <link rel="preload" href="//d3fw5vlhllyvee.cloudfront.net/m/s/scripts/react17/mobileSharedDeps.remoteEntry.0ef8d87a1f2900a0f0fb.js" as="script" crossorigin="anonymous">
#                 <script data-src="shim.1fda0d76e8ca51e8a649.js">
# (()=>{"use strict";var i={p:""};window&&window.mosaic&&window.mosaic.webpackPublicPath&&(i.p=window.mosaic.webpackPublicPath+"/"),window.mosaic=window.mosaic||{},window.mosaic.apiQueue=window.mosaic.apiQueue||[],window.mosaic.onMosaicApiReady=i=>{window.mosaic.apiQueue.push(i)},window.mosaic.loggingCallbacks=window.mosaic.loggingCallbacks||[],window.mosaic.onProviderBrowserEvent=i=>(window.mosaic.loggingCallbacks.push(i),{removeCallback:()=>{const o=window.mosaic.loggingCallbacks.indexOf(i);-1!==o&&window.mosaic.loggingCallbacks.splice(o,1)}})})();
# //# sourceMappingURL=shim.1fda0d76e8ca51e8a649.js.map</script><script data-src="SharedDepsShim.js">
# "use strict";!function(){var e=window._INDEED=window._INDEED||{},n=e.shared=e.shared||{};n.v1||(n.v1={load:function(){for(var e=arguments.length,o=new Array(e),r=0;r<e;r++)o[r]=arguments[r];return new Promise((function(e,r){n.v1.load.q.push({args:o,resolve:e,reject:r})}))},initialize:function(e){n.v1.config||(n.v1.config=e,o(3))}},n.v1.load.q=[]);var o=function e(o){if(n.v1.load.q){var r,c=n.v1.config,a=c.loadersUrl,t=null!==(r=localStorage.getItem("shared-deps.branch"))&&void 0!==r?r:c.branch;t&&(a=a.replace("sharedDepsLoaders","".concat(t,"/sharedDepsLoaders")));var s=document.createElement("script");s.async=!0,s.src=a,s.crossOrigin="anonymous",s.onerror=function(n){if(n instanceof ErrorEvent){var r=o-1;if(r>0)e(r);else{var a,t=n.error,s=n.message,i=n.filename,d=n.lineno,l=n.colno,v=(null==t?void 0:t.name)||"SharedDepsShimLoaderError",u=(null==t?void 0:t.message)||s||"Failed to fetch & execute sharedDepsLoader",m=(null==t?void 0:t.toString())||"".concat(v,": ").concat(u),h=null===(a=(null==t?void 0:t.stack)||"event: ".concat(i,":").concat(d,":").concat(l,"\nonerror: ").concat((new Error).stack))||void 0===a?void 0:a.substring(0,1e3),g=document.createElement("script");g.async=!0,g.crossOrigin="anonymous",g.src="".concat(c.logRoute,"&logType=").concat(c.jsErrorLogType,"&lth=").concat(c.jsErrorLth,"&name=").concat(v,"&message=").concat(encodeURIComponent(u),"&toString=").concat(encodeURIComponent(m),"&stack=").concat(encodeURIComponent(h)),document.head.appendChild(g)}}},document.head.appendChild(s)}}}();</script><script>
# window._INDEED.shared.v1.initialize({ publicPath: "https://d3fw5vlhllyvee.cloudfront.net/shared/", loadersUrl: "https://d3fw5vlhllyvee.cloudfront.net/shared/sharedDepsLoadersV1.autoupgrade.js", logRoute: "https://t.indeed.com/gnav/log?", jsErrorLogType: "gnavJSError", jsErrorLth: "6411ec182c6acd8714dc2d03716eed1d" });
# window._INDEED.shared.v1.load('container', { urls: ["https://d3fw5vlhllyvee.cloudfront.net/shared/react17/remoteEntry.autoupgrade.js"], container: "react17-shared", shareScope: "react17" });
# </script><script async="" src="https://d3fw5vlhllyvee.cloudfront.net/shared/sharedDepsLoadersV1.autoupgrade.js" crossorigin="anonymous"></script><link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/index.39fb594906966db1fba1.css?cacheKey=1">
# <link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/591.ce94af0448852da672ea.css">
# <link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/uip-micro-content-provider/dist/000140827ed7f46ff706/css/client-render.css">
# <link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobalert/dist/729.6e20db15455132c92705.css">
# <link rel="stylesheet" href="https://c03.s3.indeed.com/mosaic-provider-jobsearch-feedback/dist/ff2ce39b5d59b1ecf7bc/css/DislikeFeedback-client.css">
# <link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-reportcontent/dist/182.6f6e876341441dcddf66.css">
# <link rel="stylesheet" href="https://c03.s3.indeed.com/mosaic-provider-jobcards/dist/538.839fca5195fc13f431b0.css">
# <link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-passport-intercept/dist/c342f5a5bf5a96a14f3f/css/Main-client.css">
# <link rel="stylesheet" href="https://c03.s3.indeed.com/mosaic-provider-rich-search/static/593.b31a8353d44c2b27efa9.css">
# <link rel="stylesheet" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobalert/dist/338.a2c9b494eb8480c0db35.css"><link href="https://d3fw5vlhllyvee.cloudfront.net/shared/react17/remoteEntry.autoupgrade.js" as="script" crossorigin="anonymous" rel="preload"><script async="" src="https://d3fw5vlhllyvee.cloudfront.net/shared/react17/remoteEntry.autoupgrade.js" crossorigin="anonymous"></script><link href="https://d3fw5vlhllyvee.cloudfront.net/dist/header/remoteEntry.fe16e8e10fd8e4315f84.js" as="script" crossorigin="anonymous" rel="preload"><link href="https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?2" as="script" crossorigin="anonymous" rel="preload"><link href="https://d3fw5vlhllyvee.cloudfront.net/dist/footer/remoteEntry.ecd7315c49488fb17660.js" as="script" crossorigin="anonymous" rel="preload"><link href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/remoteEntry.feffc161b33653351ef4.js?cacheKey=1" as="script" crossorigin="anonymous" rel="preload"><script async="" src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/remoteEntry.feffc161b33653351ef4.js?cacheKey=1" crossorigin="anonymous"></script><link href="//d3fw5vlhllyvee.cloudfront.net/m/s/scripts/react17/mobileSharedDeps.remoteEntry.0ef8d87a1f2900a0f0fb.js" as="script" crossorigin="anonymous" rel="preload"><script async="" src="//d3fw5vlhllyvee.cloudfront.net/m/s/scripts/react17/mobileSharedDeps.remoteEntry.0ef8d87a1f2900a0f0fb.js" crossorigin="anonymous"></script><script async="" src="https://d3fw5vlhllyvee.cloudfront.net/dist/header/remoteEntry.fe16e8e10fd8e4315f84.js" crossorigin="anonymous"></script><script async="" src="https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?2" crossorigin="anonymous"></script><script async="" src="https://d3fw5vlhllyvee.cloudfront.net/dist/footer/remoteEntry.ecd7315c49488fb17660.js" crossorigin="anonymous"></script><link rel="stylesheet" type="text/css" href="https://d3fw5vlhllyvee.cloudfront.net/dist/header/8500.1947c30242ff2da69b83.css" crossorigin="anonymous" media="all"><link rel="stylesheet" type="text/css" href="https://d3fw5vlhllyvee.cloudfront.net/dist/footer/38.8c08b7968465c76698ab.css" crossorigin="anonymous" media="all"><link rel="stylesheet" type="text/css" href="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/420.685f5da0e68838ea0e4c.css" crossorigin="anonymous" media="all"><style data-emotion="css" data-s=""></style><style data-emotion="gnav-header 1gheiwz" data-s="">#gnav-main-container.gnav .gnav-header-1gheiwz{display:flex;box-sizing:border-box;margin:0;min-width:0;width:100%;min-height:3.25rem;background-color:#ffffff;justify-content:space-between;border-bottom-width:0.0625rem;border-bottom-color:#e4e2e0;border-bottom-style:none;}@media screen and (min-width: 62em){#gnav-main-container.gnav .gnav-header-1gheiwz{border-bottom-style:solid;}}</style><style data-emotion="gnav-header 1c21a75" data-s="">#gnav-main-container.gnav .gnav-header-1c21a75{border-radius:0;color:#2557a7;font-family:"Noto Sans","Helvetica Neue","Helvetica","Arial","Liberation Sans","Roboto","Noto",sans-serif;text-decoration:none;transition:border-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),background-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),opacity 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-color 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-style 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-bottom-width 200ms cubic-bezier(0.645, 0.045, 0.355, 1),border-radius 200ms cubic-bezier(0.645, 0.045, 0.355, 1),box-shadow 200ms cubic-bezier(0.645, 0.045, 0.355, 1),color 200ms cubic-bezier(0.645, 0.045, 0.355, 1);border-bottom:0.0625rem solid;cursor:pointer;color:#2d2d2d;display:inline-flex;align-items:center;height:3rem;margin:0.125rem 0.75rem 0.125rem 1rem;margin-right:1rem;border-bottom:none;}#gnav-main-container.gnav .gnav-header-1c21a75:hover{color:#164081;}#gnav-main-container.gnav .gnav-header-1c21a75:active{col ...
#
# <body class="is-desktop desktopAurora">
#     <a id="skip-nav" class="screenreader-text" href="#gnav-header-end">
#         본문으로 건너뛰기</a>
#     <div class="mosaic-zone" id="mosaic-zone-ssrSerpModals"><div id="mosaic-provider-passport-intercept" class="mosaic mosaic-provider-passport-intercept mosaic-provider-hydrated"><div data-testid="passport-intercept-type-modal"></div></div></div><main>
#         <script>
#             !function(_){_.__JS_ERROR__=[],_.onerror=function(){_.__JS_ERROR__.push(Array.prototype.slice.call(arguments))}}(window);!function(r){const t={homepage:"mobtk",viewjob:"mobvjtk",viewjobJapan:"mobvjtk",serp:"mobtk",serpJapan:"mobtk"},n={homepage:"hp",viewjob:"vj",viewjobJapan:"vjjp",serp:"srch",serpJapan:"srchjp"},p=function(e){return t[e]},d=function(e){return n[e]},c=function(){var e=r.devicePixelRatio||1,e='"pixelRatio":'+e+',"scrWidth":'+Math.floor(r.screen.width*e)+',"scrHeight":'+Math.floor(r.screen.height*e);return r.screen.orientation&&(e+=',"scrOrientation":"'+(-1<r.screen.orientation.type.indexOf("portrait")?"portrait":"landscape")+'"'),e};r.logPageLoadInfo=function(e,t,n){if(Image){var o=d(e),a=p(e);if(o&&a){t=(a=t,'"eventName":"mobPageLoadInfo","type":"mobPageLoadInfo","pageId":"'+(t=e)+'","'+p(t)+'":"'+a+'","pageName":"'+d(t)+'"');n&&r.screen&&(t+=","+c());t="/m/rpc/frontendlogging?logType=trackEvent&moduleName=event&application=indeedmobile&pageId="+e+"&data="+encodeURIComponent("{"+t+"}").replace(/%20/g,"+");const i=new Image;i.src=t,i.height=i.width=0,i.height=i.width=1,i.style.display="none",i.ariaHidden=!0,i.alt=" ",i.setAttribute("aria-hidden","true"),document.body.appendChild(i)}}}}(window);!function(r){function t(t){for(var e=t.target;e&&e!==r.documentElement;){if("A"===e.tagName){var n=e.getAttribute("data-href");return void(null!==n&&(e.setAttribute("href",n),e.removeAttribute("data-href")))}e=e.parentNode}}r.addEventListener&&("ontouchstart"in r?r.addEventListener("touchstart",t):r.addEventListener("mousedown",t))}(document);
#
#             window._initialData={"apiPaths":{},"appCommonData":null,"appliedRadius":0,"autoOpenTwoPaneIsSponsored":false,"autoOpenTwoPaneJobKey":"ed7b7e6eb72ffab8","companyBrandColor":null,"companyJobSearchQuery":null,"companyNameInQuery":null,"country":"KR","cssResetProviders":null,"desktopFooterResumePromoModel":{"linkUrl":"\u002Fpromo\u002Fresume?from=bottomResumeCTAjobsearch&trk.origin=jobsearch","trackingParams":{"trk.origin":"jobsearch","trk.variant":"FooterGrayBelow","trk.tk":"1h16744o1knuv801","trk.pos":"below","target":"resume"}},"desktopInlineResumePromoModel":{"linkText":"이력서를 등록하세요","promoText":" - 수천개의 공고에 손쉽게 지원하세요","promoURL":"\u002Fpromo\u002Fresume?from=serptop3&subfrom=resprmrtop&trk.origin=jobsearch&trk.variant=resprmrtop&trk.tk=1h16744o1knuv801"},"dgToken":null,"disclaimer":null,"displayCanonicalLink":false,"dynFiltersViewModel":null,"emailConfirmationModel":null,"employer":null,"encryptedFccId":null,"feedbackProviderMode":"SERP","globalnavFooterHTML":"<script id=\"_indeed_gnav_footer_config\" type=\"application\u002Fjson\">{\"footerVariant\":\"DESKTOP_JOBSEEKER_FOOTER\",\"desktopJobseekerFooterConfig\":{\"links\":[{\"description\":\"직종-지역-기업별\",\"href\":\"https:\u002F\u002Fkr.indeed.com\u002Fbrowsejobs\",\"dataHref\":\"https:\u002F\u002Fkr.indeed.com\u002Fbrowsejobs?from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"BrowseJobs\"},{\"description\":\"전체 보기...\",\"href\":\"https:\u002F\u002Fkr.indeed.com\u002Fworldwide\",\"dataHref\":\"https:\u002F\u002Fkr.indeed.com\u002Fworldwide?from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"Countries\"},{\"description\":\"회사 소개\",\"href\":\"https:\u002F\u002Fkr.indeed.com\u002Fabout\",\"dataHref\":\"https:\u002F\u002Fkr.indeed.com\u002Fabout?from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"About\"},{\"description\":\"고객센터\",\"href\":\"https:\u002F\u002Fsupport.indeed.com\u002Fhc\u002Fko?redirect=false\",\"dataHref\":\"https:\u002F\u002Fsupport.indeed.com\u002Fhc\u002Fko?redirect=false\\u0026from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"JobseekerHelpCenter\"}],\"impressumLinks\":[{\"description\":\"Indeed의 접근성\",\"href\":\"https:\u002F\u002Fkr.indeed.com\u002Faccessibility?hl=ko\",\"dataHref\":\"https:\u002F\u002Fkr.indeed.com\u002Faccessibility?hl=ko\\u0026from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"Accessibility\"},{\"description\":\"개인정보 센터\",\"href\":\"https:\u002F\u002Fhrtechprivacy.com\u002F\",\"dataHref\":\"https:\u002F\u002Fhrtechprivacy.com\u002F?from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"PrivacyCenter\"},{\"description\":\"쿠키\",\"href\":\"https:\u002F\u002Fhrtechprivacy.com\u002Fko\u002Fbrands\u002Fabout-indeed#Cookies\",\"dataHref\":\"https:\u002F\u002Fhrtechprivacy.com\u002Fko\u002Fbrands\u002Fabout-indeed?from=gnav-jobsearch--indeedmobile#Cookies\",\"dataGnavElementName\":\"Cookies\"},{\"description\":\"개인정보 취급방침\",\"href\":\"https:\u002F\u002Fhrtechprivacy.com\u002Fko\u002Fbrands\u002Fabout-indeed#privacypolicy\",\"dataHref\":\"https:\u002F\u002Fhrtechprivacy.com\u002Fko\u002Fbrands\u002Fabout-indeed?from=gnav-jobsearch--indeedmobile#privacypolicy\",\"dataGnavElementName\":\"Privacy\"}],\"legalLink\":{\"description\":\"약관\",\"href\":\"https:\u002F\u002Fkr.indeed.com\u002Flegal?hl=ko\",\"dataHref\":\"https:\u002F\u002Fkr.indeed.com\u002Flegal?hl=ko\\u0026from=gnav-jobsearch--indeedmobile\",\"dataGnavElementName\":\"Terms\"},\"year\":2023},\"logRoute\":\"https:\u002F\u002Ft.indeed.com\u002Fsignals\u002Fgnav\u002Flog?from=jobsearch--indeedmobile-serpglobal\\u0026parentLogId=1h16744teiedt800\\u0026hostAppTk=1h16744o1knuv801\",\"signalsLogRoute\":\"https:\u002F\u002Ft.indeed.com\u002Fsignals\u002Fv1\u002Flog?from=jobsearch--indeedmobile-serpglobal\\u0026parentLogId=1h16744teiedt800\\u0026hostAppTk=1h16744o1knuv801\",\"serviceRequestLogUID\":\"1h16744teiedt800\",\"hostAppTk\":\"1h16744o1knuv801\",\"pageId\":\"serpGlobal\",\"canonicalPageId\":\"serpglobal\",\"applicationId\": ...
#             window.addEventListener('pageshow', function(e) {
#                 if (window.performance && typeof window.performance.getEntriesByType === 'function') {
#                     const perfEntries = window.performance.getEntriesByType('navigation');
#                     if (perfEntries && perfEntries.length > 0 && perfEntries[0].type === 'back_forward') {
#                         window['_bk'] = '1';
#                     }
#                 }
#                 if (e.persisted) {
#                     window['_bk'] = '1';
#                 }
#             });
#         </script>
#
#         <div id="jobsearch-Main">
#             <span id="m-gnav-header"><span><script id="_indeed_gnav_config" type="application/json">{"isEmployer":false,"isMobile":false,"desktopPageLinks":[{"text":"검색","href":"https://kr.indeed.com/","dataHref":"https://kr.indeed.com/?from=gnav-jobsearch--indeedmobile","isHighlighted":true,"dataGnavElementName":"FindJobs"},{"text":"기업리뷰","href":"https://kr.indeed.com/companies","dataHref":"https://kr.indeed.com/companies?from=gnav-jobsearch--indeedmobile","isHighlighted":false,"dataGnavElementName":"CompanyReviews"}],"resumeLink":{"text":"이력서 등록","href":"https://kr.indeed.com/promo/resume","dataHref":"https://kr.indeed.com/promo/resume?from=gnav-jobsearch--indeedmobile","isHighlighted":false,"dataGnavElementName":"UploadYourResume"},"skipNavLinkModel":{"href":"#gnav-header-end","text":"본문으로 건너뛰기","targetText":"본문 시작","dataGnavElementName":"SkipNav"},"variantToggleLink":{"text":"기업회원 / 채용광고 (무료 체험 제공)","href":"https://kr.indeed.com/hire?co=KR\u0026hl=ko","dataHref":"https://kr.indeed.com/hire?co=KR\u0026hl=ko\u0026from=gnav-menu-jobsearch--indeedmobile\u0026ikw=gnav-header-hire\u0026isid=employerlink-KR","dataGnavElementName":"EmployersPostJob"},"country":"KR","logoHref":"/?from=gnav-jobsearch--indeedmobile","logoName":"aurora","appName":"jobsearch--indeedmobile","shouldReduceRightMargin":false,"secondaryLogoName":"ukraine_support","secondaryLogoImageUrl":"https://d3fw5vlhllyvee.cloudfront.net/dist/header/ukraine_support.7ad2b5d444bc427dbc5d.png","secondaryLogoTooltip":"","secondaryLogoAltText":"","secondaryLogoAriaHidden":true,"secondaryLogoLinkUrl":"","inboxApiHref":"https://messages.indeed.com/messaging/jobseekers/v2/summary?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1h16744teiedt800\u0026tk=1h16744o1knuv801\u0026co=KR\u0026hl=ko\u0026clientApp=GNAV","inboxHref":"https://messages.indeed.com?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1h16744teiedt800\u0026tk=1h16744o1knuv801\u0026co=KR\u0026hl=ko","logRoute":"https://t.indeed.com/signals/gnav/log?from=jobsearch--indeedmobile-serpglobal\u0026parentLogId=1h16744teiedt800\u0026hostAppTk=1h16744o1knuv801","inboxLogTuple":"gnavInbox:12140b7982d032f1660f59e3e976c72d","isShowInboxIcon":false,"selectedIcon":"","shouldLowerNavIconMinWidth":false,"shouldReduceNavIconMargins":false,"inboxLogType":"gnavInbox","inboxLth":"12140b7982d032f1660f59e3e976c72d","notificationApiHref":"https://kr.indeed.com/notifications/api/1/getNotificationsCount?client=gnav\u0026from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1h16744teiedt800\u0026tk=1h16744o1knuv801","notificationHref":"https://kr.indeed.com/notifications?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1h16744teiedt800\u0026tk=1h16744o1knuv801\u0026hl=ko","isShowNotificationIcon":false,"notificationLogType":"gnavNotification","notificationLth":"6d669dfa33371660f3e683b38b9f3ddc","myjobsApiHref":"","myjobsHref":"https://myjobs.indeed.com?from=gnav-util-jobsearch--indeedmobile\u0026gnavTK=1h16744teiedt800\u0026tk=1h16744o1knuv801\u0026co=KR\u0026hl=ko","myjobsLogTuple":"gnavMyjobs:5d9eaad2bbc69a980218f0a8aa03ae77","isMyjobsTestActive":false,"isShowMyjobsIcon":false,"myjobsTestBucket":-1,"saveIconType":"bookmark","myjobsLogType":"gnavMyjobs","myjobsLth":"5d9eaad2bbc69a980218f0a8aa03ae77","isOnlineStatusActive":false,"onlineStatusApiHref":"https://employers.indeed.com/api/v2/messaging/onlinestatus/jobseeker?indeedcsrftoken=\u0026indeedClientApplication=gnav\u0026isClosed=false","signalsLogRoute":"https://t.indeed.com/signals/v1/log?from=jobsearch--indeedmobile-serpglobal\u0026parentLogId=1h16744teiedt800\u0026hostAppTk=1h16744o1knuv801","serviceRequestLogUID":"1h16744teiedt800","hostAppTk":"1h16744o1knuv801","pageId":"serpGlobal","canonicalPageId":"serpglobal","applicationId":"jobsearch--indeedmobile","requestURL":"http://kr.indeed.com/jobs?q=python","language":"ko","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d","jsEnabledLogType":"gnavJSEnabled","jsEnabledLth":"5e9311c1001227ca5c6c32db123fb8 ...
#         <script>
#             if (window.performance !== undefined && performance.mark !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:start');
#             }
#         </script><link rel="stylesheet" type="text/css" href="https://d3fw5vlhllyvee.cloudfront.net/dist/header/jobseekerHeader.1947c30242ff2da69b83.css" crossorigin="anonymous">
# <link rel="preconnect" href="https://fonts.gstatic.com/" crossorigin="anonymous">
# <link rel="stylesheet" type="text/css" href="https://fonts.googleapis.com/css2?family=Noto+Sans%3Aital%2Cwght%400%2C400%3B0%2C700%3B1%2C400%3B1%2C700&amp;display=swap" crossorigin="anonymous">
#         <script>
#             if (window.performance !== undefined && performance.mark !== undefined && performance.measure !== undefined) {
#                 performance.mark('gnavRenderBlockingCSSHeader:end');
#                 performance.measure('gnavRenderBlockingCSSHeader', 'gnavRenderBlockingCSSHeader:start', 'gnavRenderBlockingCSSHeader:end');
#             }
#         </script>
#         <nav class="gnav" id="gnav-main-container" aria-label="기본 설정"><div data-gnav-region="Main"><div class="gnav-header-1gheiwz e37uo190"><div class="css-wnhbdt e37uo190"><button data-gnav-element-name="SkipNav" class="css-1r39gj2 e8ju0x51" style="border: 0px; clip: rect(0px, 0px, 0px, 0px); height: 1px; margin: -1px; overflow: hidden; padding: 0px; position: absolute; width: 1px; white-space: nowrap; overflow-wrap: normal;"><span>본문으로 건너뛰기</span></button><a class="gnav-Logo gnav-header-1c21a75 emf9s7v0" href="/?from=gnav-jobsearch--indeedmobile" data-gnav-element-name="Logo" id="indeed-globalnav-logo" aria-label="인디드 홈"><div class="gnav-Logo-icon" aria-hidden="true"><svg width="75" height="20" viewBox="0 0 75 20" fill="none" xmlns="http://www.w3.org/2000/svg" focusable="false" aria-hidden="true"><path fill-rule="evenodd" clip-rule="evenodd" d="M74.613 3.458c-.265-.297-.62-.448-1.1-.448-.48 0-.846.159-1.101.487-.255.317-.387.793-.387 1.417v4.524c-.59-.636-1.203-1.092-1.825-1.399a4.568 4.568 0 0 0-1.356-.397 6.917 6.917 0 0 0-.937-.06c-1.559 0-2.822.536-3.791 1.608-.958 1.072-1.438 2.56-1.438 4.472 0 .904.123 1.747.367 2.52.246.772.59 1.448 1.06 2.022a4.975 4.975 0 0 0 1.67 1.33 4.766 4.766 0 0 0 2.089.465c.345 0 .672-.029.977-.088.205-.03.397-.08.592-.14a5.086 5.086 0 0 0 1.335-.674 7.8 7.8 0 0 0 1.253-1.15v.297c0 .565.143.992.418 1.3.286.297.643.455 1.07.455.438 0 .794-.149 1.07-.435.273-.298.417-.734.417-1.318V4.758c.004-.567-.128-1.004-.383-1.3zm-3.169 12.477c-.275.575-.643 1.002-1.09 1.28-.46.279-.96.416-1.51.416h-.01a2.79 2.79 0 0 1-1.509-.435c-.459-.298-.825-.734-1.089-1.309-.264-.585-.396-1.29-.396-2.123 0-.784.121-1.477.377-2.062.245-.596.601-1.052 1.05-1.368.46-.328.97-.477 1.548-.477h.03c.541 0 1.04.158 1.499.465.459.308.825.756 1.1 1.34.275.585.408 1.29.408 2.102 0 .872-.133 1.597-.408 2.171zm-9.896.13c-.194-.168-.459-.258-.785-.258-.296 0-.52.07-.683.199-.398.356-.713.644-.96.852-.242.199-.52.397-.813.584a3.27 3.27 0 0 1-.896.399 3.798 3.798 0 0 1-1.03.128c-.081 0-.163 0-.235-.01a2.829 2.829 0 0 1-1.303-.397c-.47-.267-.836-.662-1.122-1.179-.275-.536-.418-1.15-.427-1.845h6.145c.825 0 1.466-.12 1.915-.337.46-.239.683-.735.683-1.498 0-.833-.224-1.646-.662-2.45-.438-.795-1.09-1.449-1.976-1.953-.878-.506-1.927-.754-3.16-.754h-.091c-.907.01-1.743.16-2.486.437a5.54 5.54 0 0 0-1.969 1.269 5.677 5.677 0 0 0-1.2 1.994 7.49 7.49 0 0 0-.42 2.518c0 1.925.562 3.432 1.682 4.552 1.06 1.062 2.527 1.618 4.391 1.677.103.01.213.01.327.01.876 0 1.66-.11 2.342-.337.683-.228 1.244-.507 1.694-.843.446-.347.783-.704 1.007-1.07.224-.367.337-.695.337-.963 0-.31-.1-.557-.305-.725zm-7.336-5.605c.5-.526 1.141-.784 1.926-.784h.012c.814 0 1.477.258 1.976.773.5.517.795 1.3.867 2.35h-5.698c.101-1.03.408-1.814.917-2.339zm-6.045 5.346c-.305 0-.529.07-.692.198-.387.357-.713.645-.958.853-.245.198-.51.397-.806.584-.294.179-.591.318-.906.398a3.742 3.742 0 0 1-1.03.128c-.08 0-.162 0-.234-.01a2.841 2.841 0 0 1-1.304-.396 2.932 2.932 0 0 1-1.11-1.18c-.286-.535-.429-1.15-.44-1.844h6.155c.815 0 1.456-.12 1.915-.338.448-.238.674-.734.674-1.497 0-.834-.215-1.647-.653-2.45-.438-.795-1.1-1.45-1.976-1.954-.878-.505-1.937-.753-3.158-.753h-.103c-.906.01-1.731.16-2.486.437a5.383 5.383 0 0 0-1.957 1.268 5.54 5.54 0 0 0-1.212 1.994 7.451 7.451 0 0 0-.42 2.518c0 1.925.572 3.432 1.692 4.552 1.06 1.063 2.517 1.618 4.382 1.677.112.01.212.01.326.01.886 0 1.661-.109 2.343-.336.682-.229 1.244-.507 1.691-.843.46-.348.785-.704 1.01-1.07.223-.367.337-.695.337-.964 0-.307-.103-.555-.296-.723-.202-.17-.469-.26-.784-.26zm-6.562-5.346c.499-.526 1.142-.784 1.927-.784h.011c.814 0 1.477.258 1.976.773.509.517.795 1.3.877 2.35h-5.707c.112-1.03.419-1.814.916-2.339zM6.547 17.969v-7.301c.212.02.417.029.631.029a5.514 5.514 0 0 0 2.792-.744v8.014c0 .685-.163 1.19-.48 1.528-.315.336-.733.504-1.242.504-.5 0-.897-.168-1.223-.515-.315-.336-.478-.842-.478-1.515zm29.6-14.51c-.265-.298-.631-.449-1.09-.449-.48 0-.846.159-1.102.487-.264.317-.387.793-.387 1.417v4.524c-.59-.636-1.2-1.092-1.824-1.399a ...
#     <script>
# "use strict";(()=>{const e=window._INDEED=window._INDEED||{},o=e.shared=e.shared||{};o.v1||(o.v1={load:function(){for(var e=arguments.length,n=new Array(e),r=0;r<e;r++)n[r]=arguments[r];return new Promise(((e,r)=>{o.v1.load.q.push({args:n,resolve:e,reject:r})}))},initialize:e=>{o.v1.config||(o.v1.config=e,n(3))}},o.v1.load.q=[]);const n=e=>{if(o.v1.load.q){var r;const s=o.v1.config;let a=s.loadersUrl;const t=null!==(r=localStorage.getItem("shared-deps.branch"))&&void 0!==r?r:s.branch;t&&(a=a.replace("sharedDepsLoaders",`${t}/sharedDepsLoaders`));const c=document.createElement("script");c.async=!0,c.src=a,c.crossOrigin="anonymous",c.onerror=o=>{if(o instanceof ErrorEvent){const a=e-1;if(a>0)n(a);else{var r;const{error:e,message:n,filename:a,lineno:t,colno:c}=o,d=(null==e?void 0:e.name)||"SharedDepsShimLoaderError",i=(null==e?void 0:e.message)||n||"Failed to fetch & execute sharedDepsLoader",l=(null==e?void 0:e.toString())||`${d}: ${i}`,v=null===(r=(null==e?void 0:e.stack)||`event: ${a}:${t}:${c}\nonerror: ${(new Error).stack}`)||void 0===r?void 0:r.substring(0,1e3),m=document.createElement("script");m.async=!0,m.crossOrigin="anonymous",m.src=`${s.logRoute}&logType=${s.jsErrorLogType}&lth=${s.jsErrorLth}&name=${d}&message=${encodeURIComponent(i)}&toString=${encodeURIComponent(l)}&stack=${encodeURIComponent(v)}`,document.head.appendChild(m)}}},document.head.appendChild(c)}}})();
# window._INDEED.shared.v1.initialize({"publicPath":"https://d3fw5vlhllyvee.cloudfront.net/shared/","loadersUrl":"https://d3fw5vlhllyvee.cloudfront.net/shared/sharedDepsLoadersV1.autoupgrade.js","logRoute":"https://t.indeed.com/signals/gnav/log?from=jobsearch--indeedmobile-serpglobal&parentLogId=1h16744teiedt800&hostAppTk=1h16744o1knuv801","jsErrorLogType":"gnavJSError","jsErrorLth":"6411ec182c6acd8714dc2d03716eed1d"});
# window._INDEED.shared.v1.load('container', {"urls":["https://d3fw5vlhllyvee.cloudfront.net/shared/react17/remoteEntry.autoupgrade.js"],"container":"react17-shared","shareScope":"react17"});
# </script><script>(() => {
# var callFnWhenReady = window._INDEED && window._INDEED.shared && window._INDEED.shared.v1 ? (fn) => fn() : (fn) => window.addEventListener('onSharedDepsLoadersV1Available', fn, { once: true });
# callFnWhenReady(() => window._INDEED.shared.v1.load("module", {"prereqUrls":[],"prereqContainers":["react17-shared"],"urls":["https://d3fw5vlhllyvee.cloudfront.net/dist/header/remoteEntry.fe16e8e10fd8e4315f84.js"],"container":"gnavHeaderModule","module":"./jobseekerHeader","shareScope":"react17","afterEvent":"DOMContentLoaded"}).catch(()=>null));
# })();</script><div id="gnav-script-contents">            <template style="display: none" id="sentry-json" data-json="{&quot;init&quot;:{&quot;dsn&quot;:&quot;https://2649acf65e0c47afba547cc0ea1f4846@sentry.indeed.com/43344&quot;,&quot;release&quot;:&quot;b24468f0a597206d17083c454a2ea338b98291e2&quot;},&quot;isEnabled&quot;:true,&quot;tags&quot;:{&quot;appName&quot;:&quot;jobsearch--indeedmobile&quot;},&quot;ctk&quot;:&quot;1h16744n4k3rn801&quot;}"></template>
#             <script>
#             window.IndeedSentry = window.IndeedSentry || {};
#             window.IndeedSentry.preInitErrors = [];
#             window.IndeedSentry.preInitErrorCatcher = function (error) {
#                 window.IndeedSentry.preInitErrors.push(error);
#             };
#             window.addEventListener("error", window.IndeedSentry.preInitErrorCatcher);
#             </script>
#             <script>(() => {
# var callFnWhenReady = window._INDEED && window._INDEED.shared && window._INDEED.shared.v1 ? (fn) => fn() : (fn) => window.addEventListener('onSharedDepsLoadersV1Available', fn, { once: true });
# callFnWhenReady(() => window._INDEED.shared.v1.load("js", {"urls":["https://d3fw5vlhllyvee.cloudfront.net/frontend-sentry-bundle/v1.1.2/js/sentry.js?2"],"afterEvent":"DOMContentLoaded"}).catch(()=>null));
# })();</script>
#         <script>
#             window.signals_transport = window.signals_transport || {
#                 emitSignal: function(data){
#                     window.signals_transport_tmp = window.signals_transport_tmp || [];
#                     if (window.signals_transport_tmp.length < 1000) {
#                         window.signals_transport_tmp.push(data);
#                     }
#                 }
#             };
#         </script>
#     </div></span></span><div id="jobsearch-JapanPage"><div><div class="jobsearch-JapanPageLayout jobsearch-JapanSerpContainer is-i18n"><div id="mosaic-belowNav" class="mosaic-zone"></div><div class="jobsearch-RichSearch"><div class="jobsearch-RichSearchBody"><div class="mosaic MosaicProviderRichSearchDaemon" id="MosaicProviderRichSearchDaemon"><div role="search" class="i-unmask"><div class="yosegi-InlineWhatWhere"><form class="yosegi-InlineWhatWhere-form" id="jobsearch" method="get" action="/jobs?q=python&amp;l="><div class="yosegi-InlineWhatWhere-searchBox"><div class="yosegi-EmbeddedLabelInput yosegi-InlineWhatWhere-what"><div><div class="icl-TextInputClearable"><div class="icl-TextInput"><div class="icl-TextInput-labelWrapper"><label id="label-text-input-what" class="icl-TextInput-label" for="text-input-what" tabindex="-1">검색어</label></div><div class="icl-TextInput-wrapper"><input type="text" aria-labelledby="label-text-input-what" id="text-input-what" name="q" placeholder="업종, 직무 및 회사명" value="python" autocomplete="off" aria-owns="text-input-what-suggestion-list" class="icl-TextInput-control icl-TextInput-control--withIconRight" aria-invalid="false"><span class="icl-TextInput-icon iconRight" aria-hidden="true"><span aria-hidden="true" class=""><svg xmlns="http://www.w3.org/2000/svg" width="21" height="20" fill="none" aria-hidden="true"><defs></defs><path fill="#767676" fill-rule="evenodd" d="M11.4038 12.3048C10.7084 12.7451 9.88397 13 9 13c-2.48528 0-4.5-2.0147-4.5-4.5C4.5 6.01472 6.51472 4 9 4c2.4853 0 4.5 2.01472 4.5 4.5 0 .87711-.2509 1.6956-.6849 2.3876l3.5089 3.5089c.1952.1953.1952.5119 0 .7071l-.7071.7072c-.1953.1952-.5119.1952-.7071 0l-3.506-3.506zM11.5 8.5c0 1.38071-1.1193 2.5-2.5 2.5-1.38071 0-2.5-1.11929-2.5-2.5S7.61929 6 9 6c1.3807 0 2.5 1.11929 2.5 2.5z" clip-rule="evenodd"></path></svg></span></span></div></div></div><div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px"><div id="text-input-what-suggestion-list"><div class="icl-Autocomplete-ariaResultsAvailableWrapper" style="border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px"><span aria-live="polite" aria-atomic="true" role="status" class="icl-Autocomplete-ariaResultsAvailable"></span></div><div class="icl-Autocomplete-ariaResultsAvailableWrapper" style="border:0;clip:rect(0 0 0 0);height:1px;margin:-1px;overflow:hidden;padding:0;position:absolute;width:1px"><span aria-live="polite" aria-atomic="true" role="status" class="icl-Autocomplete-ariaResultsAvailable"></span></div></div></div></div></div><div class="yosegi-EmbeddedLabelInput yosegi-InlineWhatWhere-where"><div><div class="icl-TextInputClearable"><div class="icl-TextInput"><div class="icl-TextInput-labelWrapper"><label id="label-text-input-where" class="icl-TextInput-label" for="text-input-where" tabindex="-1">지역</label></div><div class="icl-TextInput-wrapper"><input type="text" aria-labelledby="label-text-input-where" id="text-input-where" name="l" placeholder="근무지 (시,구,지하철역)" value="" autocomplete="off" aria-owns="text-input-where-suggestion-list" class="icl-TextInput-control icl-TextInput-control--withIconRight" aria-invalid="false"><span class="icl-TextInput-icon iconRight" aria-hidden="true"><span aria-hidden="true" class=""><svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="none" aria-hidden="true"><defs></defs><path fill="#767676" fill-rule="evenodd" d="M5.81104 8.2c0-2.322 1.87303-4.2 4.18889-4.2 2.31587 0 4.18887 1.878 4.18887 4.2 0 2.581-2.8123 6.1691-3.8282 7.3811-.1906.2274-.5307.2274-.72131 0C8.62332 14.3691 5.81104 10.781 5.81104 8.2zm4.1889 2.0029c1.10456 0 1.99996-.89545 1.99996-2.00002 0-1.10457-.8954-2-1.99996-2-1.10457 0-2 .89543-2 2s.89543 2.00002 2 2.00002z" clip-rule="evenodd"></path></svg></span></span></div></div></div><div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px"><div id="text-input-where-suggestion-list"><div class="ic ...
# <b>Python</b>, JavaScript, Go, etc.). About the job Join us...</div><span class="date"><span class="visually-hidden">Posted</span>30일 이상 전에 게시됨</span><span class="result-link-bar-separator">·</span><button type="button" class="sl resultLink more_links_button" aria-expanded="false">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button type="button" class="close-button" title="Close" aria-label="Close"></button><ul><li><span class="mat">모두 보기: <a href="/q-google-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">Google 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 지역 채용공고</a> - <a href="/q-software-engineer-intern-l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울지역 Software Engineer Intern 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/salaries/Software%20Engineer%20Intern/%EC%84%9C%EC%9A%B8?campaignid=serp-more&amp;fromjk=ed7b7e6eb72ffab8&amp;from=serp-more">2023 Software Engineering Intern, People with Disabilities (장애인 채용)</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div class="kebabMenu" aria-labelledby="jobActionButton-ed7b7e6eb72ffab8 jobTitle-ed7b7e6eb72ffab8" role="group"><span aria-live="polite" class="visually-hidden"></span><button id="jobActionButton-ed7b7e6eb72ffab8" aria-label="Job Actions menu is collapsed" aria-haspopup="true" aria-expanded="false" class="kebabMenu-button"><svg width="24" height="24" role="presentation" aria-hidden="true" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li><li><div class="cardOutline tapItem fs-unmask result job_5d24a062cabc9f0d resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table class="jobCard_mainContent big6_visualChanges" cellpadding="0" cellspacing="0" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a id="job_5d24a062cabc9f0d" data-mobtk="1h16744o1knuv801" data-jk="5d24a062cabc9f0d" data-hiring-event="false" target="_blank" data-hide-spinner="true" role="button" aria-label="2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" href="/rc/clk?jk=5d24a062cabc9f0d&amp;fccid=a5b4499d9e91a5c6&amp;vjs=3"><span title="2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)" id="jobTitle-5d24a062cabc9f0d">2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">Google</span><span class="ratingsDisplay withRatingLink" aria-hidden="true"><span class="ratingNumber" aria-label="4.3 out of five stars rating" role="img"><span aria-hidden="true">4.3</span><svg width="12" height="12" role="presentation" class="starIcon" aria-hidden="true" viewBox="0 0 16 16" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89 ...
# <b>Python</b>, C, or C++. About the job Student Training in Engineering Program...</div><span class="date"><span class="visually-hidden">Posted</span>30일 이상 전에 게시됨</span><span class="result-link-bar-separator">·</span><button type="button" class="sl resultLink more_links_button" aria-expanded="false">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button type="button" class="close-button" title="Close" aria-label="Close"></button><ul><li><span class="mat">모두 보기: <a href="/q-google-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">Google 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 지역 채용공고</a> - <a href="/q-engineer-l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울지역 Engineer 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/engineer/salaries/서울?campaignid=serp-more&amp;fromjk=5d24a062cabc9f0d&amp;from=serp-more">서울 지역 2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div class="kebabMenu" aria-labelledby="jobActionButton-5d24a062cabc9f0d jobTitle-5d24a062cabc9f0d" role="group"><span aria-live="polite" class="visually-hidden"></span><button id="jobActionButton-5d24a062cabc9f0d" aria-label="Job Actions menu is collapsed" aria-haspopup="true" aria-expanded="false" class="kebabMenu-button"><svg width="24" height="24" role="presentation" aria-hidden="true" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li><li><div class="cardOutline tapItem fs-unmask result job_a0f0a1cb28e20f8c resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table class="jobCard_mainContent big6_visualChanges" cellpadding="0" cellspacing="0" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a id="job_a0f0a1cb28e20f8c" data-mobtk="1h16744o1knuv801" data-jk="a0f0a1cb28e20f8c" data-hiring-event="false" target="_blank" data-hide-spinner="true" role="button" aria-label="[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" href="/rc/clk?jk=a0f0a1cb28e20f8c&amp;fccid=59060ddcdf96b101&amp;vjs=3"><span title="[송파구] 데이터분석(Python,R,모델,ML)" id="jobTitle-a0f0a1cb28e20f8c">[송파구] 데이터분석(Python,R,모델,ML)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">시니어앤파트너즈</span><div class="companyLocation">서울 송파구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg width="14" height="13" viewBox="0 0 14 13" fill="none" role="presentation" xmlns="http://www.w3.org/2000/svg" aria-label="Job type" aria-hidden="true"><path fill="#595959" fill-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" clip-rule="evenodd"></path><path fill="#595959" d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z"></path> ...
# <b>Python</b>,R,모델,ML) 회사개요 채용사는 1998... 데이터분석|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;R|인터넷...</div><span class="date"><span class="visually-hidden">Posted</span>16일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button type="button" class="sl resultLink more_links_button" aria-expanded="false">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button type="button" class="close-button" title="Close" aria-label="Close"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ec%8b%9c%eb%8b%88%ec%96%b4%ec%95%a4%ed%8c%8c%ed%8a%b8%eb%84%88%ec%a6%88-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">시니어앤파트너즈 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%86%a1%ed%8c%8c%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 송파구 지역 채용공고</a> - <a href="/q-%5b%ec%86%a1%ed%8c%8c%ea%b5%ac%5d-%eb%8d%b0%ec%9d%b4%ed%84%b0%eb%b6%84%ec%84%9d%28python%2cr%2c%eb%aa%a8%eb%8d%b8%2cml%29-l-%ec%84%9c%ec%9a%b8-%ec%86%a1%ed%8c%8c%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 송파구지역 [송파구] 데이터분석(python,r,모델,ml) 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div class="kebabMenu" aria-labelledby="jobActionButton-a0f0a1cb28e20f8c jobTitle-a0f0a1cb28e20f8c" role="group"><span aria-live="polite" class="visually-hidden"></span><button id="jobActionButton-a0f0a1cb28e20f8c" aria-label="Job Actions menu is collapsed" aria-haspopup="true" aria-expanded="false" class="kebabMenu-button"><svg width="24" height="24" role="presentation" aria-hidden="true" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li><li><div class="cardOutline tapItem fs-unmask result job_b469f992ddab8f71 resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table class="jobCard_mainContent big6_visualChanges" cellpadding="0" cellspacing="0" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle jobTitle-newJob css-bdjp2m eu4oa1w0" tabindex="-1"><a id="job_b469f992ddab8f71" data-mobtk="1h16744o1knuv801" data-jk="b469f992ddab8f71" data-hiring-event="false" target="_blank" data-hide-spinner="true" role="button" aria-label="인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" href="/rc/clk?jk=b469f992ddab8f71&amp;fccid=aa11023cc66bb11b&amp;vjs=3"><span title="인공지능 관리 및 개발자 (Python, yolo 사용자 우대)" id="jobTitle-b469f992ddab8f71">인공지능 관리 및 개발자 (Python, yolo 사용자 우대)</span></a></h2><div class="new css-ud6i3y eu4oa1w0"><span class="label css-1qj35nq eu4oa1w0">new</span></div></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">하가</span><div class="companyLocation">서울 동작구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg xmlns="http://www.w3.org/2000/svg" fill="none" viewBox="0 0 16 13" role="presentation" aria-hidden="true" aria-label="Salary"><defs></defs><path fill="#595959" fill-rule="evenodd" d="M2.45168 6.10292c-.30177-.125-.62509-.18964-.95168-.1903V4.08678c.32693-.00053.6506-.06518.95267-.1903.30331-.12564.57891-.30979.81105-.54193.23215-.23215.4163-.50775.54194-.81106.12524-.30237.18989-.62638.19029-.95365H9.0902c0 .3283.06466.65339.1903.9567.12564.30331.3 ...
# ...
#     window.mosaic.publicPaths["mosaic-provider-passport-intercept"]="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-passport-intercept/dist/";
#     window.mosaic.publicPaths["MosaicProviderRichSearchDaemon"]="https://c03.s3.indeed.com/mosaic-provider-rich-search/static/";
#     window.mosaic.publicPaths["mosaic-provider-desktopserp-jobalert-form"]="https://d3fw5vlhllyvee.cloudfront.net/mosaic-provider-jobalert/dist/";
# </script>
# <script src="https://d3fw5vlhllyvee.cloudfront.net/mosaic-common/dist/loadProviders.bc5d995d2450ce18d95a.js?cacheKey=1" async="" crossorigin="anonymous"></script>
# <script id="mosaic-translation-overrides">
#     this.mosaic = this.mosaic || {}; this.mosaic.i18nOverrides = this.mosaic.i18nOverrides || {};
# (function applyTranslations(){this['i18n.mosaic-provider-passport-intercept']={"":{"Content-Type":" text/plain; charset=UTF-8","Locale":"ko","Plural-Forms":" nplurals=1; plural=0;","Project-Name":"mosaic-provider-passport-intercept"},"Close":[null,"닫기"],"Loading login form":[null,"로그인 양식 로드 중"],"Login Form":[null,"로그인 양식"],"Login window":[null,"로그인 창"],"Prompts the user to log in to be able to see more jobs in their homepage feed\u0004To see more jobs in your personalized feed, create an account or sign in.":[null,"맞춤형 피드에서 더 많은 채용공고를 보려면 계정을 만들거나 로그인하세요."],"Prompts the user to log in to be able to see more jobs in SERP\u0004To see more than one page of jobs, create an account or sign in.":[null,"채용공고를 두 페이지 이상 보려면 계정을 만들거나 로그인하세요."],"Prompts the user to log in to be able to see more jobs in SERP\u0004To see more than two pages of jobs, create an account or sign in.":[null,"채용공고를 세 페이지 이상 보려면 계정을 만들거나 로그인하세요."]};
# this['i18n.mosaic-provider-jobcards']={"":{"Content-Type":" text/plain; charset=UTF-8","Locale":"ko","Plural-Forms":" nplurals=1; plural=0;","Project-Name":"mosaic-provider-jobcards"}," (Indeed est.)":[null,""],"(part of {0})":[null,"({0}의 자회사)"],"About Indeed's estimated salaries":[null,"인디드의 예상 급여에 대한 정보"],"About employer estimates":[null,""],"Additional job details":[null,"추가적인 채용공고 상세 정보"],"All \"{0}\" jobs removed":[null,"모든 \"{0}\" 채용공고가 제거됨"],"Always hiring":[null,"상시 채용 중"],"Applied {0}":[null,"{0} 해당공고에 지원하셨습니다"],"Apply from your phone":[null,"지금 휴대폰으로 지원하세요"],"Apply in person":[null,""],"Apply with Indeed":[null,""],"Apply with resume":[null,""],"Archived {0}":[null,"{0}에 보관됨"],"Based on jobs you explored":[null,""],"Call the employer":[null,""],"Close":[null,"닫기"],"Commute duration":[null,""],"Direct interview":[null,""],"Directly schedule interview":[null,""],"Easily arrange interviews":[null,"간편하게 면접 예약"],"Employer est.":[null,""],"Estimated {0}":[null,"예상 급여: {0}"],"Expired":[null,"만료됨"],"Failed to save job":[null,"관심취업정보 저장 실패"],"Failed to unsave job":[null,"채용공고 저장 취소 실패"],"Fast hiring":[null,""],"Glassdoor collaboration":[null,""],"Highly rated company":[null,""],"Hired {0}":[null,"{0} 채용됨"],"Hiring ongoing":[null,"채용 진행 중"],"Hiring quickly":[null,""],"In collaboration with Glassdoor":[null,""],"Indeed Connect":[null,""],"Indeed est.":[null,""],"Indeed shows estimated salaries when employers don’t include a salary in their job post. The estimated salary of [{0}|salaryRange] is based on reports from employees with similar jobs, employer postings for similar jobs, and salary information from the same location. These figures are given to the Indeed users for the purpose of generalized comparison only.":[null,"인디드에서는 채용기업이 채용공고 게시에 급여를 포함하지 않은 경우 예상 급여를 보여줍니다. [{0}|salaryRange]의 예상 급여는 유사 직종의 직원, 유사 직종의 채용기업 게시물 및 동일 지역 급여 정보의 보고서를 기준으로 합니다. 이러한 수치는 일반적인 비교 목적으로만 인디드 사용자에게 제공됩니다."],"Interview times available":[null,"면접 예약 가능"],"Interviewing {0}":[null,"{0}에 면접"],"Interviews On The Spot":[null,"현장 면접"],"Interviews on the Spot":[null,"현장 면접"],"Job Actions":[null,"채용공고 작업"],"Job Actions Dialog":[null,""],"Job Actions menu is collapsed":[null,""],"Job Location":[null,""],"Job Saved, Job Actions":[null,""],"Job available at {0} locations":[null,""],"Job preferences updated":[null,"채용공고 기본 설정이 업데이트됨"],"Job type":[null,""],"Jobs matching your preferences and resume.":[null,"개인 설정 및 이력서와 일치하는 채용공고입니다."],"Manage job preferences":[null,"채용공고 기본 설정 관리"],"Manage profile":[null,"프로필 관리"],"Meet the Hiring Manager":[null,"채용 관리자와 만남"],"More jobs that match your search.":[null,"검색과 일치하는 더 많은 채용공고입니다."],"New":[null,""],"Not interested":[null,"관심 없음"],"Offered {0}":[null,"{0}에 입사요청 받음"],"Offers On The Spot":[null,"현장 입사요청"],"Offers on the Spot":[null,"현장 입사요청"],"Other jobs you might like":[null,""],"Other search results.":[null,"기타 검색 결과입니다."],"Personalized matches.":[null,"맞춤형 일치 항목입니다."],"Priority hiring":[null,""],"Profile updated":[null,"프로필 업데이트됨"],"RSVP to the Event":[null,""],"Reload page to see updated jobs":[null,"페이지를 새로 고쳐 업데이트된 채용공고 확인"],"Remote type":[null,"원격 근무 유형"],"Remove saved job":[null,"저장된 채용공고 삭제"],"Report job":[null,"신고하기"],"Reported":[null,""],"Reporting":[null,""],"Request an interview":[null,""],"Requirements":[null,"필수 사항"],"Resume insights":[null,"이력서 인사이트"],"Salary":[null,""],"Same {0} job in {1} other location":["Same {0} job in {1} other locations","{1}개 다른 위치의 동일한 {0} 채용공고"],"Save job":[null,"채용공고 저장"],"Saved {0}":[null,"{0}에 저장됨"],"Shift":[null,""],"Similar jobs recruiting nationwide":[null,"전국에서 채용 중인 유사한 채용공고"],"Smart fill available":[null,"Smart Fill 사용 가능"],"Transit information":[null,""],"Undo":[null,"실행 취소"],"Urgently hiring":[null,"긴급 채용 중"],"View all locations":[null,""],"Visited {0}":[null,"{0}에 조회함"],"We detected that the salary for this job is [{0}|salaryRange]. While this information [comes from the employer|emphasis], our detections are not always accurate, so we display it as an employ ...
# this['i18n.MosaicProviderRichSearchDaemon']={"":{"Content-Type":" text/plain; charset=UTF-8","Locale":"ko_KR","Plural-Forms":" nplurals=1; plural=0;"},"'Apply from your phone' jobs":[null,"휴대폰으로 지원 가능한 공고"],"All Filters":[null,""],"All Job Types":[null,""],"All filters":[null,"필터 더보기"],"Back":[null,"이전"],"Cancel":[null,"취소"],"Clear":[null,""],"Clear {0} filter":[null,"{0} 필터 지우기"],"Current Location":[null,"현재 지역"],"Distance":[null,""],"Edit search radius":[null,""],"Employment type":[null,""],"Exact location":[null,"정확한 지역"],"Filter {0} has been removed":[null,""],"Filters":[null,"필터"],"Filters Applied":[null,""],"Job Type":[null,"채용공고 유형"],"New":[null,"신규"],"New jobs":[null,"신규 채용공고"],"No":[null,"아니요"],"Remove {0}":[null,""],"Reset":[null,"선택 초기화"],"Salary":[null,"급여"],"Search jobs at all companies":[null,""],"Search jobs at {0}":[null,""],"Select and press backspace to search jobs at all companies":[null,""],"Select region":[null,""],"Sort by date":[null,""],"Sort by relevance":[null,""],"Update":[null,"업데이트"],"Yes":[null,"예"],"near {0}":[null,""],"search":[null,""],"{0} miles":[null,"{0}킬로미터"],"{0} search suggestion":["{0} search suggestions","{0} 검색 추천"],"japan rich search salary\u0004${0}":[null,""],"japan rich search salary\u0004Daily":[null,""],"japan rich search salary\u0004Hourly":[null,""],"japan rich search salary\u0004Maximum Salary":[null,""],"japan rich search salary\u0004Minimum Salary":[null,""],"japan rich search salary\u0004Monthly":[null,""],"japan rich search salary\u0004No limit":[null,""],"japan rich search salary\u0004None":[null,""],"japan rich search salary\u0004Not set":[null,""],"japan rich search salary\u0004The minimum value must be less than the maximum value":[null,""],"japan rich search salary\u0004Yearly":[null,""],"japan rich search salary\u0004above {0}":[null,""],"japan rich search salary\u0004above {0} {1}":[null,""],"japan rich search salary\u0004below {0} {1}":[null,""],"japan rich search salary\u0004{0} - {1} {2}":[null,""],"japan search component\u0004(Complete with just your email address)":[null,""],"japan search component\u0004<span class=\"jpsearchcomponent-SaveSearchToast-link\">The selected search criteria</span> has been saved":[null,""],"japan search component\u0004Account creation disclaimer":[null,""],"japan search component\u0004All jobs":[null,""],"japan search component\u0004All jobs in {0}":[null,""],"japan search component\u0004All methods":[null,""],"japan search component\u0004Area":[null,""],"japan search component\u0004By creating a job alert or receiving a recommended job alert, the user is deemed to have agreed to the <a {0}>Terms of Use</a>.":[null,""],"japan search component\u0004By creating an Indeed account, you agree to the <a {0}>Terms of Use</a>, <a {1}>Cookie policy</a>, and <a {2}>Privacy Policy</a>.":[null,""],"japan search component\u0004Cafe, Nutritionist etc.":[null,""],"japan search component\u0004Cancel":[null,""],"japan search component\u0004Complete selection":[null,""],"japan search component\u0004Confirm":[null,""],"japan search component\u0004Create account":[null,""],"japan search component\u0004Create account with LINE":[null,""],"japan search component\u0004Create account with email":[null,""],"japan search component\u0004Daily rate is not applicable for fulltime":[null,""],"japan search component\u0004Decide":[null,""],"japan search component\u0004Do you already have an account?":[null,""],"japan search component\u0004Don't show me this message again":[null,""],"japan search component\u0004Exact Location":[null,""],"japan search component\u0004Hourly rate is not applicable for fulltime":[null,""],"japan search component\u0004Hourly wage, annual income, etc.":[null,""],"japan search component\u0004Job Age":[null,""],"japan search component\u0004Job Features":[null,""],"japan search component\u0004Let us send you jobs matching your condition!":[null,""],"japan search component\u0004Login":[null,""],"japan search component\u0004Login is required ...
# </script>
# <script type="text/javascript" async="">
#                 function loadScript() {
#                     if (!window.gtag) {
#                         var script = document.createElement('script');
#                         var done = false;
#                         var head = document.getElementsByTagName("head")[0];
#                         script.src = 'https://www.googletagmanager.com/gtag/js?id=DC-' + 8232301;
#                         script.onload = script.onreadystatechange = function() {
#                             if ( !done && (!this.readyState || this.readyState == "loaded" || this.readyState == "complete") ) {
#                                 done = true;
#                                 configureGtag();
#                                 // IE memory leak
#                                 script.onload = script.onreadystatechange = null;
#                                 head.removeChild( script );
#                             }
#                         };
#                         head.appendChild(script);
#                     }
#                 }
#                 function configureGtag() {
#                     window.dataLayer = window.dataLayer || [];
#                     window.gtag = function(){dataLayer.push(arguments);}
#                     gtag('js', new Date());
#                     gtag('config', 'DC-' + 8232301);
#                 }
#                 loadScript();
#             </script>
#         <script>
#                 var _comscore = _comscore || [];
#                 _comscore.push({ c1: "2", c2: "6486505", c4:"http://kr.indeed.com/jobs?q=python", c15:""});
#                 (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#             </script>
#             <noscript>
#                 <img src="https://sb.scorecardresearch.com/p?c1=2&c2=6486505&c4=&c15=&cv=2.0&cj=1" style="display:none" width="0" height="0" alt="" />
#             </noscript>
#         </main>
# <script>(function(){var js = "window['__CF$cv$params']={r:'7cc37af12ce6ee01',m:'xxRNoO75kzH.tgJXPLzXdw_nIc.Hmjf6IgSw6xJoKqQ-1684909724-0-AWtNSnXl1vHK+qSm4uBQQlI7Z86QzJPMqxWLwfK3a2Ii',u:'/cdn-cgi/challenge-platform/h/g'};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/invisible.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.nonce = '';_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script><iframe height="1" width="1" style="position: absolute; top: 0px; left: 0px; border: none; visibility: hidden;"></iframe><script defer="" src="https://static.cloudflareinsights.com/beacon.min.js/v52afc6f149f6479b8c77fa569edb01181681764108816" integrity="sha512-jGCTpDpBAYDGNYR5ztKt4BQPGef1P0giN6ZGVUi835kFF88FOmmn8jBQWNgrNd8g/Yu421NdgWhwQoaOPFflDw==" data-cf-beacon="{&quot;rayId&quot;:&quot;7cc37af12ce6ee01&quot;,&quot;token&quot;:&quot;47161d92b8b74ef5b23469b91c2535c6&quot;,&quot;version&quot;:&quot;2023.4.0&quot;,&quot;si&quot;:100}" crossorigin="anonymous"></script>
#
#
# <script type="text/javascript" data-qa="gnav-google-analytics">
# if (!window.ga) {
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#     ga('create','UA-90780-1','auto',{allowLinker:true});
#     ga('set', 'transport', 'beacon');
#     ga('require','linkid');
#     ga('require','linker');
#     ga('linker:autoLink', [
#         'indeed.co.in',
#         'indeed.lu',
#         'indeed.fr',
#         'indeed.de',
#         'indeed.com.br',
#         'indeed.co.uk',
#         'indeed.hk',
#         'indeed.fi',
#         'indeed.pt',
#         'indeed.jp',
#         'indeed.com',
#         'indeed.com.sg',
#         'indeed.nl',
#         'indeed.com.pk',
#         'indeed.cl',
#         'indeed.es',
#         'indeed.co.ve',
#         'indeed.ae',
#         'indeed.com.mx',
#         'indeed.com.my',
#         'indeed.ch',
#         'indeed.com.co',
#         'indeed.com.ph',
#         'indeed.co.za',
#         'indeed.ie',
#         'indeed.com.au',
#         'indeed.ca',
#         'indeed.com.pe'
#     ]);
#
#     ga('require','displayfeatures');
#     ga('send','pageview');
# }
# </script><script src="https://accounts.google.com/gsi/client"></script><img src="https://t.indeed.com/signals/gnav/log/?hostAppTk=1h16744o1knuv801&amp;canonicalPageId=serpglobal&amp;appName=jobsearch--indeedmobile&amp;connectionType=4g&amp;parentLogId=1h16744teiedt800&amp;logType=gnavPageSpeed&amp;lth=12783140239867f5afc3bd80a743e013&amp;application=globalnav&amp;navigationStart=0&amp;unloadEventStart=-1&amp;unloadEventEnd=-1&amp;redirectStart=-1&amp;redirectEnd=-1&amp;fetchStart=2&amp;domainLookupStart=2&amp;domainLookupEnd=2&amp;connectStart=2&amp;connectEnd=2&amp;secureConnectionStart=-1&amp;requestStart=195&amp;responseStart=523&amp;responseEnd=544&amp;domLoading=531&amp;domInteractive=846&amp;domContentLoadedEventStart=848&amp;domContentLoadedEventEnd=849&amp;domComplete=1685&amp;loadEventStart=1686&amp;loadEventEnd=1690&amp;navTimeApiIsSupported=1&amp;navigationType=-1&amp;redirectCount=-1&amp;paintTimingApiIsSupported=1&amp;firstPaint=886&amp;firstContentfulPaint=886" width="1" height="1" alt=" " aria-hidden="true" style="display: none;"></body></html>

# %%
type(browser)
# Out:
# selenium.webdriver.chrome.webdriver.WebDriver

# %% [markdown]
# ---

# %% [markdown]
# <img src = '2.png' height ='500' width = '500'>

# %% [markdown]
# ## Recursive
#
#
# 1. find 로 `ul` 찾음
#
#
# 2. find_all 로 `ul` 안에 li 모두 찾음 (li 안에 li)
#
#
# - `ul` 바로 안에 `li` 만을 찾길 원함.
# -  `li` 안에 `li` 제외
# - 1 level 만 들어감 깊게 들어가는거 방지

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

browser.get(f"{base_url}?q={search_term}")

# --- bs4 처리 

soup = BeautifulSoup(browser.page_source, "html.parser")

job_list = soup.find("ul", class_="jobsearch-ResultsList")

jobs = job_list.find_all('li', recursive=False)

# ul 태그 내부, li 태그 (1 level)의 개수 출력
print(len(jobs))
print()

# jobs 리스트, li 태그 데이터 출력
for job in jobs:
    print(job)
    print()
# Out:
# 18
#
# <li><div class="cardOutline tapItem fs-unmask result job_ed7b7e6eb72ffab8 resultWithShelf sponTapItem desktop vjs-highlight css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="ed7b7e6eb72ffab8" data-mobtk="1h167dravknto804" href="/rc/clk?jk=ed7b7e6eb72ffab8&amp;fccid=a5b4499d9e91a5c6&amp;vjs=3" id="job_ed7b7e6eb72ffab8" role="button" target="_blank"><span id="jobTitle-ed7b7e6eb72ffab8" title="2023 Software Engineering Intern, People with Disabilities (장애인 채용)">2023 Software Engineering Intern, People with Disabilities (장애인 채용)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">Google</span><span aria-hidden="true" class="ratingsDisplay withRatingLink"><span aria-label="4.3 out of five stars rating" class="ratingNumber" role="img"><span aria-hidden="true">4.3</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></path></svg></span></span><div class="companyLocation">서울</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>인턴</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">purpose programming languages (e.g., Java, C/C++, C#, Objective-C,
# <b>Python</b>, JavaScript, Go, etc.). About the job Join us...</div><span class="date"><span class="visually-hidden">Posted</span>30일 이상 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-google-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">Google 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 지역 채용공고</a> - <a href="/q-software-engineer-intern-l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울지역 Software Engineer Intern 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/salaries/Software%20Engineer%20Intern/%EC%84%9C%EC%9A%B8?campaignid=serp-more&amp;fromjk=ed7b7e6eb72ffab8&amp;from=serp-more">2023 Software Engineering Intern, People with Disabilities (장애인 채용)</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-ed7b7e6eb72ffab8 jobTitle-ed7b7e6eb72ffab8" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-ed7b7e6eb72ffab8"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_5d24a062cabc9f0d resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="5d24a062cabc9f0d" data-mobtk="1h167dravknto804" href="/rc/clk?jk=5d24a062cabc9f0d&amp;fccid=a5b4499d9e91a5c6&amp;vjs=3" id="job_5d24a062cabc9f0d" role="button" target="_blank"><span id="jobTitle-5d24a062cabc9f0d" title="2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)">2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">Google</span><span aria-hidden="true" class="ratingsDisplay withRatingLink"><span aria-label="4.3 out of five stars rating" class="ratingNumber" role="img"><span aria-hidden="true">4.3</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></path></svg></span></span><div class="companyLocation">서울</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">related field. Programming experience in Java,
# <b>Python</b>, C, or C++. About the job Student Training in Engineering Program...</div><span class="date"><span class="visually-hidden">Posted</span>30일 이상 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-google-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">Google 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 지역 채용공고</a> - <a href="/q-engineer-l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울지역 Engineer 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/engineer/salaries/서울?campaignid=serp-more&amp;fromjk=5d24a062cabc9f0d&amp;from=serp-more">서울 지역 2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-5d24a062cabc9f0d jobTitle-5d24a062cabc9f0d" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-5d24a062cabc9f0d"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_a0f0a1cb28e20f8c resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="a0f0a1cb28e20f8c" data-mobtk="1h167dravknto804" href="/rc/clk?jk=a0f0a1cb28e20f8c&amp;fccid=59060ddcdf96b101&amp;vjs=3" id="job_a0f0a1cb28e20f8c" role="button" target="_blank"><span id="jobTitle-a0f0a1cb28e20f8c" title="[송파구] 데이터분석(Python,R,모델,ML)">[송파구] 데이터분석(Python,R,모델,ML)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">시니어앤파트너즈</span><div class="companyLocation">서울 송파구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">[송파구] 데이터분석(
# <b>Python</b>,R,모델,ML) 회사개요 채용사는 1998... 데이터분석|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;R|인터넷...</div><span class="date"><span class="visually-hidden">Posted</span>16일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ec%8b%9c%eb%8b%88%ec%96%b4%ec%95%a4%ed%8c%8c%ed%8a%b8%eb%84%88%ec%a6%88-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">시니어앤파트너즈 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%86%a1%ed%8c%8c%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 송파구 지역 채용공고</a> - <a href="/q-%5b%ec%86%a1%ed%8c%8c%ea%b5%ac%5d-%eb%8d%b0%ec%9d%b4%ed%84%b0%eb%b6%84%ec%84%9d%28python%2cr%2c%eb%aa%a8%eb%8d%b8%2cml%29-l-%ec%84%9c%ec%9a%b8-%ec%86%a1%ed%8c%8c%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 송파구지역 [송파구] 데이터분석(python,r,모델,ml) 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-a0f0a1cb28e20f8c jobTitle-a0f0a1cb28e20f8c" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-a0f0a1cb28e20f8c"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_b469f992ddab8f71 resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle jobTitle-newJob css-bdjp2m eu4oa1w0" tabindex="-1"><a aria-label="인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="b469f992ddab8f71" data-mobtk="1h167dravknto804" href="/rc/clk?jk=b469f992ddab8f71&amp;fccid=aa11023cc66bb11b&amp;vjs=3" id="job_b469f992ddab8f71" role="button" target="_blank"><span id="jobTitle-b469f992ddab8f71" title="인공지능 관리 및 개발자 (Python, yolo 사용자 우대)">인공지능 관리 및 개발자 (Python, yolo 사용자 우대)</span></a></h2><div class="new css-ud6i3y eu4oa1w0"><span class="label css-1qj35nq eu4oa1w0">new</span></div></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">하가</span><div class="companyLocation">서울 동작구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Salary" fill="none" role="presentation" viewbox="0 0 16 13" xmlns="http://www.w3.org/2000/svg"><defs></defs><path clip-rule="evenodd" d="M2.45168 6.10292c-.30177-.125-.62509-.18964-.95168-.1903V4.08678c.32693-.00053.6506-.06518.95267-.1903.30331-.12564.57891-.30979.81105-.54193.23215-.23215.4163-.50775.54194-.81106.12524-.30237.18989-.62638.19029-.95365H9.0902c0 .3283.06466.65339.1903.9567.12564.30331.30978.57891.54193.81106.23217.23215.50777.41629.81107.54193.3032.12558.6281.19024.9562.1903v1.83556c-.3242.00155-.6451.06616-.9448.19028-.3033.12563-.5789.30978-.81102.54193-.23215.23214-.4163.50774-.54193.81106-.12332.2977-.18789.61638-.19024.93849H3.99496c-.00071-.32645-.06535-.64961-.19029-.95124-.12564-.30332-.30979-.57891-.54193-.81106-.23215-.23215-.50775-.4163-.81106-.54193zM0 .589843C0 .313701.223858.0898438.5.0898438h12.0897c.2762 0 .5.2238572.5.5000002V9.40715c0 .27614-.2238.5-.5.5H.5c-.276143 0-.5-.22386-.5-.5V.589843zM6.54427 6.99849c1.10457 0 2-.89543 2-2s-.89543-2-2-2-2 .89543-2 2 .89543 2 2 2zm8.05523-2.69917v7.10958H2.75977c-.27615 0-.5.2238-.5.5v.5c0 .2761.22385.5.5.5H15.422c.4419 0 .6775-.2211.6775-.6629V4.29932c0-.27615-.2239-.5-.5-.5h-.5c-.2761 0-.5.22385-.5.5z" fill="#595959" fill-rule="evenodd"></path></svg>연봉 35,000,000원 - 60,000,000원</div></div><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>계약직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">[직무내용] tensorflow serving, 인공지능 모델과 연동되는 백엔드(
# <b>python</b>, flask) API서버 개발 [근무시간 및 형태] 주 5일 근무 (오전) 9시 00분~(오후) 6시 00분 주소정근로시간 : 40...</div><span class="date"><span class="visually-hidden">Posted</span>5일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ed%95%98%ea%b0%80-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">하가 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%eb%8f%99%ec%9e%91%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 동작구 지역 채용공고</a> - <a href="/q-%ea%b4%80%eb%a6%ac-%ed%94%84%eb%a1%9c%ea%b7%b8%eb%9e%a8-%ea%b0%9c%eb%b0%9c%ec%9e%90-l-%ec%84%9c%ec%9a%b8-%eb%8f%99%ec%9e%91%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 동작구지역 관리 프로그램 개발자 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/salaries/%EA%B4%80%EB%A6%AC%20%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%A8%20%EA%B0%9C%EB%B0%9C%EC%9E%90/%EC%84%9C%EC%9A%B8%20%EB%8F%99%EC%9E%91%EA%B5%AC?campaignid=serp-more&amp;fromjk=b469f992ddab8f71&amp;from=serp-more">인공지능 관리 및 개발자 (Python, yolo 사용자 우대)</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-b469f992ddab8f71 jobTitle-b469f992ddab8f71" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-b469f992ddab8f71"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_5594832db046013e resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="IT분야 직업훈련교사의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="5594832db046013e" data-mobtk="1h167dravknto804" href="/rc/clk?jk=5594832db046013e&amp;fccid=af1182589e05cf0b&amp;vjs=3" id="job_5594832db046013e" role="button" target="_blank"><span id="jobTitle-5594832db046013e" title="IT분야 직업훈련교사">IT분야 직업훈련교사</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">재단법인 한국아이티교육재단</span><div class="companyLocation">서울 서초구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">바일·게임&gt;빅데이터·AI(인공지능)&gt;인공지능(AI)|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;데이터분석|인터넷·IT·통신·모바일·게임&gt;빅데이터...</div><span class="date"><span class="visually-hidden">Posted</span>8일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ec%9e%ac%eb%8b%a8%eb%b2%95%ec%9d%b8-%ed%95%9c%ea%b5%ad%ec%95%84%ec%9d%b4%ed%8b%b0%ea%b5%90%ec%9c%a1%ec%9e%ac%eb%8b%a8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">재단법인 한국아이티교육재단 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%84%9c%ec%b4%88%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 서초구 지역 채용공고</a> - <a href="/q-it%eb%b6%84%ec%95%bc-%ec%a7%81%ec%97%85%ed%9b%88%eb%a0%a8%ea%b5%90%ec%82%ac-l-%ec%84%9c%ec%9a%b8-%ec%84%9c%ec%b4%88%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 서초구지역 It분야 직업훈련교사 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-5594832db046013e jobTitle-5594832db046013e" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-5594832db046013e"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="mosaic-zone nonJobContent-desktop" id="mosaic-afterFifthJobResult"><div class="mosaic uip-micro-content-provider" id="uip-micro-content-provider"><div class="micro-content-injection-wrapper"></div></div></div></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_e8f858ada4b36c5c resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="e8f858ada4b36c5c" data-mobtk="1h167dravknto804" href="/rc/clk?jk=e8f858ada4b36c5c&amp;fccid=0bed8e17bc113980&amp;vjs=3" id="job_e8f858ada4b36c5c" role="button" target="_blank"><span id="jobTitle-e8f858ada4b36c5c" title="[2023 Summer Internship] MedTech – Business Excellence">[2023 Summer Internship] MedTech – Business Excellence</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">Johnson &amp; Johnson</span><span aria-hidden="true" class="ratingsDisplay withRatingLink"><span aria-label="4.2 out of five stars rating" class="ratingNumber" role="img"><span aria-hidden="true">4.2</span><svg aria-hidden="true" class="starIcon" fill="none" height="12" role="presentation" viewbox="0 0 16 16" width="12" xmlns="http://www.w3.org/2000/svg"><path d="M8 12.8709L12.4542 15.5593C12.7807 15.7563 13.1835 15.4636 13.0968 15.0922L11.9148 10.0254L15.8505 6.61581C16.1388 6.36608 15.9847 5.89257 15.6047 5.86033L10.423 5.42072L8.39696 0.640342C8.24839 0.289808 7.7516 0.289808 7.60303 0.640341L5.57696 5.42072L0.395297 5.86033C0.015274 5.89257 -0.13882 6.36608 0.149443 6.61581L4.0852 10.0254L2.90318 15.0922C2.81653 15.4636 3.21932 15.7563 3.54584 15.5593L8 12.8709Z" fill="#767676"></path></svg></span></span><div class="companyLocation">서울</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>임시직<span class="more-items"> +<!-- -->1</span></div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">분석에 익숙한 자 2) 데이터 분석 및 시각화 도구 사용 경험(Tableau, Power BI, Excel,
# <b>Python</b> 등) 3) 프로젝트 관리에 대한 이해와 경험 &lt;2023 Summer Internship 공통 사항...</div><span class="date"><span class="visually-hidden">Posted</span>14일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-johnson-&amp;-johnson-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">Johnson &amp; Johnson 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 지역 채용공고</a> - <a href="/q-%5b2023-summer-internship%5d-medtech-%e2%80%93-business-excellence-l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울지역 [2023 Summer Internship] Medtech – Business Excellence 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-e8f858ada4b36c5c jobTitle-e8f858ada4b36c5c" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-e8f858ada4b36c5c"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_25b3c3e6a66bd77c resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="25b3c3e6a66bd77c" data-mobtk="1h167dravknto804" href="/rc/clk?jk=25b3c3e6a66bd77c&amp;fccid=fe227fbd2afb9580&amp;vjs=3" id="job_25b3c3e6a66bd77c" role="button" target="_blank"><span id="jobTitle-25b3c3e6a66bd77c" title="그룹공동 마이데이터 분석 플랫폼(데이터분석가)">그룹공동 마이데이터 분석 플랫폼(데이터분석가)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">KB데이타시스템</span><div class="companyLocation">서울 마포구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">인터넷·IT·통신·모바일·게임&gt;통신·모바일&gt;플랫폼(VM)|인터넷·IT·통신·모바일·게임&gt;응용프로그래머&gt;
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;응용프로그래머&gt;머신러닝(ML)|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공...</div><span class="date"><span class="visually-hidden">Posted</span>30일 이상 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat"><a href="/q-kb%eb%8d%b0%ec%9d%b4%ed%83%80%ec%8b%9c%ec%8a%a4%ed%85%9c-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html" rel="nofollow">KB데이타시스템 취업정보</a> 전체 검색 - <a href="/l-%ec%84%9c%ec%9a%b8-%eb%a7%88%ed%8f%ac%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 마포구 지역 취업</a> 검색</span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-25b3c3e6a66bd77c jobTitle-25b3c3e6a66bd77c" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-25b3c3e6a66bd77c"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_bb17e4528555174f resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle jobTitle-newJob css-bdjp2m eu4oa1w0" tabindex="-1"><a aria-label="`23년 상반기 아비커스 공개의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="bb17e4528555174f" data-mobtk="1h167dravknto804" href="/rc/clk?jk=bb17e4528555174f&amp;fccid=ee13651dcbd31376&amp;vjs=3" id="job_bb17e4528555174f" role="button" target="_blank"><span id="jobTitle-bb17e4528555174f" title="`23년 상반기 아비커스 공개">`23년 상반기 아비커스 공개</span></a></h2><div class="new css-ud6i3y eu4oa1w0"><span class="label css-1qj35nq eu4oa1w0">new</span></div></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">HD현대그룹</span><div class="companyLocation">서울</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">동화(API,UI) 구축 및 운영 경험 - CI/CD에 대한 이해 -
# <b>Python</b> 사용 가능 근무지 서울 모집인원 0명 직무 소프트웨어 플랫폼 (경력... 경력 : 관련 경력 4년 이상 ㆍ
# <b>Python</b>, C 등 프로그래밍 능력 보유...</div><span class="date"><span class="visually-hidden">Posted</span>2일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat"><a href="/q-hd%ed%98%84%eb%8c%80%ea%b7%b8%eb%a3%b9-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html" rel="nofollow">HD현대그룹 취업정보</a> 전체 검색 - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 지역 취업</a> 검색</span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-bb17e4528555174f jobTitle-bb17e4528555174f" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-bb17e4528555174f"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_95a7a9b4c00f9ada resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="인공지능(AI) 기술 개발(신입)의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="95a7a9b4c00f9ada" data-mobtk="1h167dravknto804" href="/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&amp;ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&amp;jk=95a7a9b4c00f9ada&amp;fccid=dd616958bd9ddc12&amp;vjs=3" id="job_95a7a9b4c00f9ada" role="button" target="_blank"><span id="jobTitle-95a7a9b4c00f9ada" title="인공지능(AI) 기술 개발(신입)">인공지능(AI) 기술 개발(신입)</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">(주)RGA Inc.</span><div class="companyLocation">서울 강남역</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata salary-snippet-container"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Salary" fill="none" role="presentation" viewbox="0 0 16 13" xmlns="http://www.w3.org/2000/svg"><defs></defs><path clip-rule="evenodd" d="M2.45168 6.10292c-.30177-.125-.62509-.18964-.95168-.1903V4.08678c.32693-.00053.6506-.06518.95267-.1903.30331-.12564.57891-.30979.81105-.54193.23215-.23215.4163-.50775.54194-.81106.12524-.30237.18989-.62638.19029-.95365H9.0902c0 .3283.06466.65339.1903.9567.12564.30331.30978.57891.54193.81106.23217.23215.50777.41629.81107.54193.3032.12558.6281.19024.9562.1903v1.83556c-.3242.00155-.6451.06616-.9448.19028-.3033.12563-.5789.30978-.81102.54193-.23215.23214-.4163.50774-.54193.81106-.12332.2977-.18789.61638-.19024.93849H3.99496c-.00071-.32645-.06535-.64961-.19029-.95124-.12564-.30332-.30979-.57891-.54193-.81106-.23215-.23215-.50775-.4163-.81106-.54193zM0 .589843C0 .313701.223858.0898438.5.0898438h12.0897c.2762 0 .5.2238572.5.5000002V9.40715c0 .27614-.2238.5-.5.5H.5c-.276143 0-.5-.22386-.5-.5V.589843zM6.54427 6.99849c1.10457 0 2-.89543 2-2s-.89543-2-2-2-2 .89543-2 2 .89543 2 2 2zm8.05523-2.69917v7.10958H2.75977c-.27615 0-.5.2238-.5.5v.5c0 .2761.22385.5.5.5H15.422c.4419 0 .6775-.2211.6775-.6629V4.29932c0-.27615-.2239-.5-.5-.5h-.5c-.2761 0-.5.22385-.5.5z" fill="#595959" fill-rule="evenodd"></path></svg>연봉 70,000,000원 - 100,000,000원</div></div><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"><td class="shelfItem indeedApply"><span class="iaIcon"></span><span class="ialbl iaTextBlack">간편지원</span></td><td class="shelfItem hiringMultipleCandidates"><div class="hiringMultipleCandidatesCaption"><span class="hiringMultipleCandidatesIcon"></span>여러 지원자 채용 중</div></td></tr><tr class="underShelfFoot ...
# <b>Python</b>, C++개발 경험 * PyTorch, Tensorflow등의 머신러닝 툴 경험자 *※ 코딩 능력 우수인...</div><span class="date"><span class="visually-hidden">Employer</span>1일 전 활성화됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-(%ec%a3%bc)rga-inc.-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">(주)RGA Inc. 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ea%b0%95%eb%82%a8%ec%97%ad-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">강남역 지역 채용공고</a> - <a href="/q-%ec%9d%b8%ea%b3%b5%ec%a7%80%eb%8a%a5(ai)-%ea%b8%b0%ec%88%a0-%ea%b0%9c%eb%b0%9c(%ec%8b%a0%ec%9e%85)-l-%ec%84%9c%ec%9a%b8-%ea%b0%95%eb%82%a8%ec%97%ad-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 강남역지역 인공지능(ai) 기술 개발(신입) 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-95a7a9b4c00f9ada jobTitle-95a7a9b4c00f9ada" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-95a7a9b4c00f9ada"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_3af3cac46966cc13 resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle jobTitle-newJob css-bdjp2m eu4oa1w0" tabindex="-1"><a aria-label="빅데이터플랫폼 / Python 개발자의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="3af3cac46966cc13" data-mobtk="1h167dravknto804" href="/rc/clk?jk=3af3cac46966cc13&amp;fccid=d22d7c6a99de76b6&amp;vjs=3" id="job_3af3cac46966cc13" role="button" target="_blank"><span id="jobTitle-3af3cac46966cc13" title="빅데이터플랫폼 / Python 개발자">빅데이터플랫폼 / Python 개발자</span></a></h2><div class="new css-ud6i3y eu4oa1w0"><span class="label css-1qj35nq eu4oa1w0">new</span></div></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">핸디소프트</span><div class="companyLocation">안양 동안구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet"><b>Python</b> 개발자 채용 우리 회사에 대해 4줄 이내로 소개해주세요 모집부문 및 자격요건 담당업무 자격요건 인원
# <b>Python</b>, Docker 등 백엔드 개발ㆍ정부과제 진행(컨테이너 기반의 빅데이터 플랫폼 관리)ㆍ
# ...
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;머신러닝|인터넷·IT·통신·모바일·게임&gt;빅데이터...</div><span class="date"><span class="visually-hidden">Posted</span>13일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ec%82%ac%eb%8b%a8%eb%b2%95%ec%9d%b8-%ed%95%9c%ea%b5%ad%ec%84%9c%eb%b9%84%ec%8a%a4%ec%82%b0%ec%97%85%ec%a7%84%ed%9d%a5%ec%9b%90-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">사단법인 한국서비스산업진흥원 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ec%a2%85%eb%a1%9c%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 종로구 지역 채용공고</a> - <a href="/q-%ec%9d%b8%ea%b3%b5%ec%a7%80%eb%8a%a5(ai),-%ec%9d%b8%ea%b3%b5%ec%a7%80%eb%8a%a5(ai)-%ec%99%b8-%ec%8b%a0%ec%9e%85-l-%ec%84%9c%ec%9a%b8-%ec%a2%85%eb%a1%9c%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 종로구지역 인공지능(ai), 인공지능(ai) 외 신입 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-c5112e132f7f1e05 jobTitle-c5112e132f7f1e05" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-c5112e132f7f1e05"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_71c47ac87bb4087e resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="71c47ac87bb4087e" data-mobtk="1h167dravknto804" href="/rc/clk?jk=71c47ac87bb4087e&amp;fccid=230e414668234579&amp;vjs=3" id="job_71c47ac87bb4087e" role="button" target="_blank"><span id="jobTitle-71c47ac87bb4087e" title="기술 인턴 인공지능 응용 연구/개발 인턴">기술 인턴 인공지능 응용 연구/개발 인턴</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">써로마인드로보틱스</span><div class="companyLocation">서울 관악구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>인턴</div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">6개월) (협의) *모집 절차: 서류 à인터뷰(오프라인) *지원 자격: 프로그래밍 언어 활용 능력:
# <b>Python</b>, C, C++ 중 1가지 이상 데이터구조, 알고리즘 과목 이수 머신러닝과 딥러닝의 기본 개념 이해 머신러닝...</div><span class="date"><span class="visually-hidden">Posted</span>30일 이상 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ec%8d%a8%eb%a1%9c%eb%a7%88%ec%9d%b8%eb%93%9c%eb%a1%9c%eb%b3%b4%ed%8b%b1%ec%8a%a4-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">써로마인드로보틱스 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%ea%b4%80%ec%95%85%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 관악구 지역 채용공고</a> - <a href="/q-%ec%9d%b8%ed%84%b4-l-%ec%84%9c%ec%9a%b8-%ea%b4%80%ec%95%85%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 관악구지역 인턴 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/%EC%9D%B8%ED%84%B4/salaries/서울-관악구?campaignid=serp-more&amp;fromjk=71c47ac87bb4087e&amp;from=serp-more">서울 관악구 지역 기술 인턴 인공지능 응용 연구/개발 인턴</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-71c47ac87bb4087e jobTitle-71c47ac87bb4087e" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-71c47ac87bb4087e"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_c71d26dc7e43def1 resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle jobTitle-newJob css-bdjp2m eu4oa1w0" tabindex="-1"><a aria-label="부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="c71d26dc7e43def1" data-mobtk="1h167dravknto804" href="/rc/clk?jk=c71d26dc7e43def1&amp;fccid=05b9e3e68be655f0&amp;vjs=3" id="job_c71d26dc7e43def1" role="button" target="_blank"><span id="jobTitle-c71d26dc7e43def1" title="부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]">부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]</span></a></h2><div class="new css-ud6i3y eu4oa1w0"><span class="label css-1qj35nq eu4oa1w0">new</span></div></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">한국전자금융</span><div class="companyLocation">서울 마포구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직<span class="more-items"> +<!-- -->1</span></div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">및 운영 경험 서버가상화 등 가상화 기반 시스템 및 클라우드 서비스 운영관리 경험 스크립트(Shell,
# <b>Python</b> 등)를 활용한 인프라 운영관리 네트워크 및 보안솔루션, 웹서비스, DBMS의 기본지식 비즈니스 이해도 및...</div><span class="date"><span class="visually-hidden">Posted</span>7일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%ed%95%9c%ea%b5%ad%ec%a0%84%ec%9e%90%ea%b8%88%ec%9c%b5-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">한국전자금융 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%eb%a7%88%ed%8f%ac%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 마포구 지역 채용공고</a> - <a href="/q-it-%ea%b8%b0%ec%88%a0%ec%a7%80%ec%9b%90-l-%ec%84%9c%ec%9a%b8-%eb%a7%88%ed%8f%ac%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 마포구지역 IT 기술지원 취업</a></span></li><li><span class="mat">급여 조회: <a href="/career/salaries/IT%20%EA%B8%B0%EC%88%A0%EC%A7%80%EC%9B%90/%EC%84%9C%EC%9A%B8%20%EB%A7%88%ED%8F%AC%EA%B5%AC?campaignid=serp-more&amp;fromjk=c71d26dc7e43def1&amp;from=serp-more">부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-c71d26dc7e43def1 jobTitle-c71d26dc7e43def1" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-c71d26dc7e43def1"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="cardOutline tapItem fs-unmask result job_79d696388d32d3ff resultWithShelf sponTapItem desktop css-kyg8or eu4oa1w0"><div class="slider_container css-77eoo7 eu4oa1w0" dir="auto"><div class="slider_list css-kyg8or eu4oa1w0"><div class="slider_item css-kyg8or eu4oa1w0"><div class="job_seen_beacon"><table cellpadding="0" cellspacing="0" class="jobCard_mainContent big6_visualChanges" role="presentation"><tbody><tr><td class="resultContent"><div class="css-1m4cuuf e37uo190"><h2 class="jobTitle css-1h4a4n5 eu4oa1w0" tabindex="-1"><a aria-label="백엔드 엔지니어 (Python) 정규직의 전체 세부 정보" class="jcs-JobTitle css-jspxzf eu4oa1w0" data-hide-spinner="true" data-hiring-event="false" data-jk="79d696388d32d3ff" data-mobtk="1h167dravknto804" href="/rc/clk?jk=79d696388d32d3ff&amp;fccid=dd6f5fd8e8c02e7e&amp;vjs=3" id="job_79d696388d32d3ff" role="button" target="_blank"><span id="jobTitle-79d696388d32d3ff" title="백엔드 엔지니어 (Python) 정규직">백엔드 엔지니어 (Python) 정규직</span></a></h2></div><div class="heading6 company_location tapItem-gutter companyInfo"><span class="companyName">데이터비</span><div class="companyLocation">서울 마포구</div></div><div class="heading6 tapItem-gutter metadataContainer noJEMChips salaryOnly"><div class="metadata"><div class="attribute_snippet" data-testid="attribute_snippet_testid"><svg aria-hidden="true" aria-label="Job type" fill="none" height="13" role="presentation" viewbox="0 0 14 13" width="14" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M4.50226.5c-.27614 0-.5.223858-.5.5v2.1H.5c-.276142 0-.5.22386-.5.5v1.9h14V3.6c0-.27614-.2239-.5-.5-.5h-3.4977V1c0-.276142-.22389-.5-.50004-.5h-5Zm4.19962 2.6H5.30344V1.8h3.39844v1.3Z" fill="#595959" fill-rule="evenodd"></path><path d="M5.70117 6.80005H0v5.20005c0 .2761.223857.5.5.5h13c.2761 0 .5-.2239.5-.5V6.80005H8.30117v.80322c0 .27614-.22386.5-.5.5h-1.6c-.27614 0-.5-.22386-.5-.5v-.80322Z" fill="#595959"></path></svg>정규직<span class="more-items"> +<!-- -->1</span></div></div></div><div class="heading6 error-text tapItem-gutter"></div></td></tr></tbody></table><table class="jobCardShelfContainer big6_visualChanges" role="presentation"><tbody><tr class="jobCardShelf"></tr><tr class="underShelfFooter"><td><div class="heading6 tapItem-gutter result-footer"><div class="job-snippet">인터넷·IT·통신·모바일·게임&gt;웹프로그래머&gt;
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;응용프로그래머&gt;
# <b>Python</b>|인터넷·IT·통신·모바일·게임&gt;빅데이터·AI(인공지능)&gt;
# <b>Python</b></div><span class="date"><span class="visually-hidden">Posted</span>25일 전에 게시됨</span><span class="result-link-bar-separator">·</span><button aria-expanded="false" class="sl resultLink more_links_button" type="button">더보기</button></div><div class="tab-container"><div class="more-links-container result-tab"><div class="more_links"><button aria-label="Close" class="close-button" title="Close" type="button"></button><ul><li><span class="mat">모두 보기: <a href="/q-%eb%8d%b0%ec%9d%b4%ed%84%b0%eb%b9%84-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">데이터비 취업정보</a> - <a href="/l-%ec%84%9c%ec%9a%b8-%eb%a7%88%ed%8f%ac%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 마포구 지역 채용공고</a> - <a href="/q-%eb%b0%b1%ec%97%94%eb%93%9c-%ec%97%94%ec%a7%80%eb%8b%88%ec%96%b4-(python)-%ec%a0%95%ea%b7%9c%ec%a7%81-l-%ec%84%9c%ec%9a%b8-%eb%a7%88%ed%8f%ac%ea%b5%ac-%ec%b1%84%ec%9a%a9%ea%b3%b5%ea%b3%a0.html">서울 마포구지역 백엔드 엔지니어 (python) 정규직 취업</a></span></li></ul></div></div></div></td></tr></tbody></table><div aria-live="polite"></div></div></div><div class="slider_sub_item css-kyg8or eu4oa1w0"></div></div></div><div aria-labelledby="jobActionButton-79d696388d32d3ff jobTitle-79d696388d32d3ff" class="kebabMenu" role="group"><span aria-live="polite" class="visually-hidden"></span><button aria-expanded="false" aria-haspopup="true" aria-label="Job Actions menu is collapsed" class="kebabMenu-button" id="jobActionButton-79d696388d32d3ff"><svg aria-hidden="true" fill="none" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M12 7C13.1 7 14 6.1 14 5C14 3.9 13.1 3 12 3C10.9 3 10 3.9 10 5C10 6.1 10.9 7 12 7ZM12 10C10.9 10 10 10.9 10 12C10 13.1 10.9 14 12 14C13.1 14 14 13.1 14 12C14 10.9 13.1 10 12 10ZM12 17C10.9 17 10 17.9 10 19C10 20.1 10.9 21 12 21C13.1 21 14 20.1 14 19C14 17.9 13.1 17 12 17Z" fill="#2d2d2d"></path></svg></button></div></div><span aria-live="polite" class="visually-hidden"></span></li>
#
# <li><div class="mosaic-zone nonJobContent-desktop" id="mosaic-afterFifteenthJobResult"></div></li>

# %% [markdown]
# ---

# %% [markdown]
# ## 데이터 필터링
#
# - jobs 리스트 중
#
# ###  None
#
# - 무언가 '없읍'
#
# - false 랑 다름
#
# - html 데이터 -> ul -> li (recursive=False)
#
# - 이 후 필터링 으로 "div", class_="mosaic-zone" 데이터 처리

# %% [markdown]
# <img src = '3.png' height ='500' width = '500'>

# %%
# li 태그 중 class 네임에 따라 출력, # find, none 논리로 출력 

for job in jobs:
    
    zone = job.find("div", class_="mosaic-zone")
    if zone == None:
        print("job li")
    else:
        print("mosaic li")
# Out:
# job li
# job li
# job li
# job li
# job li
# mosaic li
# job li
# job li
# job li
# job li
# job li
# mosaic li
# job li
# job li
# job li
# job li
# job li
# mosaic li

# %% [markdown]
# ---

# %%
# class name으로 데이터 필터링

for job in jobs:
        
    if job.find("div", class_="cardOutline"):
        print("job li")
    else:
        print("mosaic li")
# Out:
# job li
# job li
# job li
# job li
# job li
# mosaic li
# job li
# job li
# job li
# job li
# job li
# mosaic li
# job li
# job li
# job li
# job li
# job li
# mosaic li

# %% [markdown]
# ---

# %% [markdown]
# ## Select
#
# - select_one > dict 형으로 한번에
#
# - find_all('') > 태그 를 리스트화
#
#
# - https://nomadcoders.co/python-for-beginners/lectures/3801

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

options = Options()

browser = webdriver.Chrome(options=options)

base_url = "https://kr.indeed.com/jobs"
search_term = "python"

browser.get(f"{base_url}?q={search_term}")

# --- bs4 처리 

soup = BeautifulSoup(browser.page_source, "html.parser")

job_list = soup.find("ul", class_="jobsearch-ResultsList")

jobs = job_list.find_all('li', recursive=False)


# li 태그 중 class 네임에 따라 출력,
# find, none 논리로 출력 

results = []

for job in jobs:
    
    zone = job.find("div", class_="mosaic-zone")
    
    if zone == None:
        
        # anchor = job.find_all('a') # list

        anchor = job.select_one('h2 a') # dict
        
        title = anchor['aria-label']
        link = anchor['href']
        
        company = job.find('span', class_='companyName')
        location = job.find('div', class_='companyLocation')
    
        # dict 데이터 형
        job_data = {
            'position': title,
            'link': f"https://kr.indeed.com{link}",
            'company': company.string,
            'location': location.string
        }
        
        # 결과 리스트 append
        results.append(job_data)

    
for result in results:
    print(result)
    print()
# Out:
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}

# %%
print(title)
# Out:
# 백엔드 엔지니어 (Python) 정규직의 전체 세부 정보

# %%
print(link)
# Out:
# /rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3

# %%
print(company)
# Out:
# <span class="companyName">데이터비</span>

# %%
print(location)
# Out:
# <div class="companyLocation">서울 마포구</div>

# %% [markdown]
# ---

# %% [markdown]
# ## pages
#
#
# - 페이지가 1개
#
# - 페이지가 여러개, 이동 버튼 없음
#
# - 페이지가 여러개, 이동 버튼 있음 (6개이상 존재)

# %% [markdown]
# 1. 태그랑, class 네임 둘다 변경 `nav`, `div`, `css-jbuxu0 ecydgvn0`
#
#
# 2. `pagination = soup.find('nav', class_='css-jbuxu0 ecydgvn0')`   시 일단 모두 생성됨. none 으로 return x 일단 생성 o
#
#
# 3. `pages = pagination.find_all('div', recursive=False)` 있으면 리스트화, 없으면 [] 빈 리스트
#     - <class 'bs4.element.ResultSet'>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


def get_page_count(keyword):
    
    options = Options()
    browser = webdriver.Chrome(options=options)

    base_url = "https://kr.indeed.com/jobs"
    browser.get(f"{base_url}?q={keyword}")
    
    soup = BeautifulSoup(browser.page_source, "html.parser")
    
    pagination = soup.find('nav', class_='css-jbuxu0 ecydgvn0')    
    
    pages = pagination.find_all('div', recursive=False)
    
    length = len(pages)
    
    # 5를 초과하는 6 이상 부터는 처리 하지 않을 예정
    if length == 0:
        return 1
    elif length > 5:
        return 5
    else: 
        return length

# %%
get_page_count('react')
# Out:
# 5

# %%
get_page_count('nest')
# Out:
# 1

# %%
get_page_count('python')
# Out:
# 5

# %% [markdown]
# ## Refactoring - 2
#
# - 함수화
# - pages 추가

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


def extract_indeed_jobs(keyword):
    
    pages = get_page_count(keyword)
    
    for page in range(pages):
        
        options = Options()

        browser = webdriver.Chrome(options=options)
        
        base_url = "https://kr.indeed.com/jobs"
        search_term = f'{keyword}'

        browser.get(f"{base_url}?q={search_term}")

        # --- bs4 처리 

        soup = BeautifulSoup(browser.page_source, "html.parser")

        job_list = soup.find("ul", class_="jobsearch-ResultsList")

        jobs = job_list.find_all('li', recursive=False)


        # li 태그 중 class 네임에 따라 출력,
        # find, none 논리로 출력 

        results = []

        for job in jobs:

            zone = job.find("div", class_="mosaic-zone")

            if zone == None:

                # anchor = job.find_all('a') # list

                anchor = job.select_one('h2 a') # dict

                title = anchor['aria-label']
                link = anchor['href']

                company = job.find('span', class_='companyName')
                location = job.find('div', class_='companyLocation')

                # dict 데이터 형
                job_data = {
                    'position': title,
                    'link': f"https://kr.indeed.com{link}",
                    'company': company.string,
                    'location': location.string
                }

                # 결과 리스트 append
                results.append(job_data)

        for result in results:
            print(result)
            print()

# %%
# 1번 페이지 5번 반복 

extract_indeed_jobs('python')
# Out:
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}

# %% [markdown]
# ---

# %% [markdown]
# `options = Options()`
# `browser = webdriver.Chrome(options=options)`
#
# 를 함수 내에서 실행시키게 해야함.
#
# - 켜져있는 상태로, 한번 더 켜지면, 봇 의심
#
# - 함수 내에서 오픈하게 되면, 실행 후, 꺼지고, 다시 실행
#
# - 오픈, 카운트, 클로즈
#
# - 1~5. 오픈, 출력, 클로즈

# %% [markdown]
# ---

# %% [markdown]
# ## Refactoring -3
#
# - 1 ~ 5 번페이지 start 처리
#
# - page 에 따라 start 부분 처리 x(0), 10, 20
#
# - start를 0처리 하면, start 없이 요청 하는것과 같은 결과가 나옴
#
# - result 빼서 처리

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


def extract_indeed_jobs(keyword):
    
    pages = get_page_count(keyword)
    
    results = []
  
    for page in range(pages):
        
        options = Options()

        browser = webdriver.Chrome(options=options)
        
        base_url = "https://kr.indeed.com/jobs"
        search_term = f'{keyword}'

        browser.get(f"{base_url}?q={search_term}&start={page*10}")

        # --- bs4 처리 

        soup = BeautifulSoup(browser.page_source, "html.parser")

        job_list = soup.find("ul", class_="jobsearch-ResultsList")

        jobs = job_list.find_all('li', recursive=False)


        # li 태그 중 class 네임에 따라 출력,
        # find, none 논리로 출력 


        for job in jobs:

            zone = job.find("div", class_="mosaic-zone")

            if zone == None:

                # anchor = job.find_all('a') # list

                anchor = job.select_one('h2 a') # dict

                title = anchor['aria-label']
                link = anchor['href']

                company = job.find('span', class_='companyName')
                location = job.find('div', class_='companyLocation')

                # dict 데이터 형
                job_data = {
                    'position': title,
                    'link': f"https://kr.indeed.com{link}",
                    'company': company.string,
                    'location': location.string
                }

                # 결과 리스트 append
                results.append(job_data)

    
    for result in results:
        print(result)
        print()

# %%
extract_indeed_jobs('python')
# Out:
# {'position': '2023 Software Engineering Intern, People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ed7b7e6eb72ffab8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '2023 Student Training in Engineering Program (STEP), People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5d24a062cabc9f0d&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[송파구] 데이터분석(Python,R,모델,ML)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a0f0a1cb28e20f8c&fccid=59060ddcdf96b101&vjs=3', 'company': '시니어앤파트너즈', 'location': '서울 송파구'}
#
# {'position': '인공지능 관리 및 개발자 (Python, yolo 사용자 우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b469f992ddab8f71&fccid=aa11023cc66bb11b&vjs=3', 'company': '하가', 'location': '서울 동작구'}
#
# {'position': 'IT분야 직업훈련교사의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5594832db046013e&fccid=af1182589e05cf0b&vjs=3', 'company': '재단법인 한국아이티교육재단', 'location': '서울 서초구'}
#
# {'position': '[2023 Summer Internship] MedTech – Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e8f858ada4b36c5c&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': '그룹공동 마이데이터 분석 플랫폼(데이터분석가)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=25b3c3e6a66bd77c&fccid=fe227fbd2afb9580&vjs=3', 'company': 'KB데이타시스템', 'location': '서울 마포구'}
#
# {'position': '`23년 상반기 아비커스 공개의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=bb17e4528555174f&fccid=ee13651dcbd31376&vjs=3', 'company': 'HD현대그룹', 'location': '서울'}
#
# {'position': '인공지능(AI) 기술 개발(신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)RGA-Inc.&ti=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%28ai%29+%EA%B8%B0%EC%88%A0+%EA%B0%9C%EB%B0%9C%28%EC%8B%A0%EC%9E%85%29&jk=95a7a9b4c00f9ada&fccid=dd616958bd9ddc12&vjs=3', 'company': '(주)RGA Inc.', 'location': '서울 강남역'}
#
# {'position': '빅데이터플랫폼 / Python 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3af3cac46966cc13&fccid=d22d7c6a99de76b6&vjs=3', 'company': '핸디소프트', 'location': '안양 동안구'}
#
# {'position': 'php, java, python(api연동) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d47b5236f7e4a7b8&fccid=2a4ae9e231fe1079&vjs=3', 'company': '메타유니버스', 'location': '서울 중구'}
#
# {'position': '인공지능(AI), 인공지능(AI) 외 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c5112e132f7f1e05&fccid=03ad1f6903097dae&vjs=3', 'company': '사단법인 한국서비스산업진흥원', 'location': '서울 종로구'}
#
# {'position': '기술 인턴 인공지능 응용 연구/개발 인턴의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=71c47ac87bb4087e&fccid=230e414668234579&vjs=3', 'company': '써로마인드로보틱스', 'location': '서울 관악구'}
#
# {'position': '부문별 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c71d26dc7e43def1&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 마포구'}
#
# {'position': '백엔드 엔지니어 (Python) 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=79d696388d32d3ff&fccid=dd6f5fd8e8c02e7e&vjs=3', 'company': '데이터비', 'location': '서울 마포구'}
#
# {'position': 'Boeing Korea Summer Intern_Software Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=9261f808b885e89a&fccid=edae4285faf6c2f0&vjs=3', 'company': 'BOEING', 'location': '서울'}
#
# {'position': '(AI개발자) python활용의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4c8e7cc0d6848534&fccid=27b797a8598f2610&vjs=3', 'company': '비지언스', 'location': '서울 금천구'}
#
# {'position': '데이터분석 신입/경력 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=88960e11c2cdd682&fccid=72348558bd9456ba&vjs=3', 'company': '블록스퀘어서울', 'location': '서울 서초구'}
#
# {'position': '[메이저 금융그룹 연구소] Data Scientist 경력직 연구원 포지션의 전체 세부 정보', 'link': 'https://kr.indeed.com/company/%EB%8D%94-%ED%9C%B4%EB%A8%BC/jobs/%EC%97%B0%EA%B5%AC%EC%86%8C-%EC%97%B0%EA%B5%AC%EC%9B%90-f8a5bc05f47465f8?fccid=3cfe13845f73c09f&vjs=3', 'company': '메이저 금융그룹 연구소', 'location': '서울'}
#
# {'position': '[인공지능개발] AI Developer를 모십니다.의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)%EB%B0%94%EC%9D%B4%EC%98%A4%EC%97%90%EC%9D%B4%EC%95%84%EC%9D%B4&ti=%5B%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EA%B0%9C%EB%B0%9C%5D+Ai+Developer%EB%A5%BC+%EB%AA%A8%EC%8B%AD%EB%8B%88%EB%8B%A4.&jk=393d36ead0df8531&fccid=2bf1cac26c8a5833&vjs=3', 'company': '(주)바이오에이아이', 'location': '서울'}
#
# {'position': 'DNN 모델 개발 엔지니어의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=303d8c644a5f2e0f&fccid=e34932b8232a173b&vjs=3', 'company': '딥엑스', 'location': '성남 분당구'}
#
# {'position': 'IT Manager - Data Scientist의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d646b6fdb341deec&fccid=2da0dedf6df97194&vjs=3', 'company': 'Procter & Gamble', 'location': '서울'}
#
# {'position': '[KITRI] IT 정보 보안/개발 교육생의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8274c2d094ef24ac&fccid=f065bd051552743e&vjs=3', 'company': '한국정보기술연구원', 'location': '서울'}
#
# {'position': '음성합성/음색변환 및 Music 생성 기술 전문가의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=7b3fb1b029354bc4&fccid=ce2f0f28b40a5be8&vjs=3', 'company': '에스케이텔레콤', 'location': '서울 중구'}
#
# {'position': '차량 제어SW 개발/PM 부문 경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=06162e62a5cc6b53&fccid=d5a22a3e93377742&vjs=3', 'company': '현대오토에버', 'location': '서울 강남구'}
#
# {'position': '2023년 상시 [신입/경력] 개발자 중의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=5939f1161708ca93&fccid=0673ca84bc014599&vjs=3', 'company': '사이냅소프트', 'location': '서울 강서구'}
#
# {'position': '[에코마케팅] Data Integration Engineer 연계형인턴/사원의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=db40aa474036f12f&fccid=5d3316a6c97b8577&vjs=3', 'company': '에코마케팅', 'location': '서울'}
#
# {'position': 'AI 연구개발자 전문연구요원(병역특례)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d8052c1b4677239a&fccid=e391d8e930358bac&vjs=3', 'company': '라이트비전', 'location': '서울 성동구'}
#
# {'position': 'Associate Customer Engineer, Data Analytics, Google Cloud, gReach Program for People with Disabilities (장애인 채용)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1c352a43e087ad61&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '[2023 Summer Internship] MedTech - Business Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=fedd89e18af95c50&fccid=dd564dec75d08f91&vjs=3', 'company': '한국존슨앤드존슨메디칼', 'location': '서울 용산구'}
#
# {'position': '2023년 2분기 정규직(신입&경력)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=6740ae9621d4b66a&fccid=7c3898912578b6c7&vjs=3', 'company': '나이스피앤아이', 'location': '서울 여의도역'}
#
# {'position': '[취업축하금300] 미스고 웹 크롤러 - 주거안정비 지원의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=dcea8f10155e3061&fccid=28ad02baea3e6b67&vjs=3', 'company': '미스고', 'location': '서울 강남구'}
#
# {'position': '자율주행 센서퓨전 개발[연구원, 책임연구원]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=02839b1c3823ddd5&fccid=980d6ecc399a3373&vjs=3', 'company': '현대자동차그룹', 'location': '서울 강남구'}
#
# {'position': '[신입] 미래 인재 DB의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8488f46665d1b77a&fccid=d5a22a3e93377742&vjs=3', 'company': '현대오토에버', 'location': '서울'}
#
# {'position': '딥러닝 AI 개발 연구원의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=87309d3ff40ead61&fccid=ce871e9e4a9f430a&vjs=3', 'company': '베이리스', 'location': '성남 수정구'}
#
# {'position': '백엔드 개발자(인턴십)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=b7223c792bfcbcd4&fccid=5013eca338141e7d&vjs=3', 'company': '액스', 'location': '서울 서초구'}
#
# {'position': 'Engineering internship in Sweden!의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=73f84a6025e969d5&fccid=1c1f99bc5683e9f2&vjs=3', 'company': 'Iknal Semikan', 'location': '서울'}
#
# {'position': '[한국 휴렛팩커드] Determined AI - Developer Support Engineer (부장급)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ee3417f78526645a&fccid=453a1d72c82baf2d&vjs=3', 'company': '한국휴렛팩커드 유한회사', 'location': '서울 영등포구'}
#
# {'position': 'Software Engineer, Applied Machine Learning, Edge TPU의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=32c7dc89fa6d4ca8&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '백엔드개발자, 모바일앱 개발자, 블록체인 개발자 신입의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=52049395e06b34cb&fccid=8b01882cef0e8002&vjs=3', 'company': '와이즈텍', 'location': '서울 용산구'}
#
# {'position': '[데브툴즈] Front end 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a76e48ed8883b9b5&fccid=ad60a0632f3f3e71&vjs=3', 'company': '데브툴즈', 'location': '안양 동안구'}
#
# {'position': '웹개발, 프론트엔드 신입/경력 계약직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=f498a784c28d03bb&fccid=5fc71e9cbda0dfc6&vjs=3', 'company': '뮤레파코리아', 'location': '성남 수정구'}
#
# {'position': '[NHN Enterprise] 클라우드 플랫폼 운영 엔지니어의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=90a7214a62825dba&fccid=c6959d0e760ece96&vjs=3', 'company': '엔에이치엔엔터프라이즈', 'location': '성남 분당구'}
#
# {'position': '(시간제)B2B 소프트웨어 운영 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=f60dd6eaff468d50&fccid=6110e8c63f0c3bbf&vjs=3', 'company': '법틀', 'location': '서울 성동구'}
#
# {'position': '2023년 DIgital Lab 전문계약직 상시의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e45e43017a6ea1f&fccid=f152288f3dcf6e51&vjs=3', 'company': 'GS칼텍스', 'location': '서울 강남구'}
#
# {'position': '웹개발, 백엔드 외 신입/경력 정규직의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e3f3b7e2103d9bc7&fccid=e60f835b4d91f8e6&vjs=3', 'company': '코인챗', 'location': '서울 강남구'}
#
# {'position': '[데브시스터즈] DevOps Engineer (신입)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=3058f7280a2e6644&fccid=58a9a803698a0afd&vjs=3', 'company': '데브시스터즈', 'location': '서울 강남구'}
#
# {'position': '[People with Disabilities] Boeing Korea Summer Intern_Software Engineer의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=784d33be59a5a14a&fccid=edae4285faf6c2f0&vjs=3', 'company': 'BOEING', 'location': '서울'}
#
# {'position': '상반기 각 부문 신입/경력 수시 [IT/개발/SW/공무/기술지원/총무/영업 외]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=cab6bc36f2e4a48e&fccid=05b9e3e68be655f0&vjs=3', 'company': '한국전자금융', 'location': '서울 서대문구'}
#
# {'position': '㈜쓰리케이비카스 java, python개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=f3a9254e8166a1ad&fccid=4ad5c4a25536f2d0&vjs=3', 'company': '쓰리케이비카스', 'location': '서울 강동구'}
#
# {'position': 'Tensor Processing Unit Architect, Silicon의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=39d5b62f514313d4&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '사세확장으로 인한 Web 솔루션 개발자 (정규직)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2d1598a6cf0de722&fccid=da67757fa8b368d8&vjs=3', 'company': '더파워브레인스', 'location': '서울 금천구'}
#
# {'position': '대기업계열 모빌리티 데이터 분석 모델 개발 (신입/경력)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=fc4ce8e7031b4ab0&fccid=0f76eb1d9acd6c10&vjs=3', 'company': '경연파트너스', 'location': '서울 용산구'}
#
# {'position': '[2023 Summer Internship] MedTech – Strategic Commercial Excellence의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2926e817928cf0c5&fccid=0bed8e17bc113980&vjs=3', 'company': 'Johnson & Johnson', 'location': '서울'}
#
# {'position': 'AI Consultant, Google Cloud Consulting의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8b0465ded60da05e&fccid=a5b4499d9e91a5c6&vjs=3', 'company': 'Google', 'location': '서울'}
#
# {'position': '응용프로그램, Web 개발 엔지니어의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2226f969e09c5c80&fccid=9952b8a561919689&vjs=3', 'company': '에이피에스티', 'location': '서울 강서구'}
#
# {'position': '[2023 전문연구요원] AI R&D-Language AI의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=7da87f6985949b06&fccid=a1e4e21b1f33cf40&vjs=3', 'company': '엔씨소프트', 'location': '성남 판교역'}
#
# {'position': '위시켓과 함께할 서버개발자님의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=a3a65a4d59061430&fccid=533c91503ff32d48&vjs=3', 'company': '위시켓', 'location': '서울 강남구'}
#
# {'position': 'Robotics Engineer [Computer Vision][연구원, 책임연구원]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=d18652df74e7a983&fccid=980d6ecc399a3373&vjs=3', 'company': '현대자동차그룹', 'location': '대한민국'}
#
# {'position': '데이터 사이언티스트 (경력1년이상우대)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=590e155f288bd18b&fccid=f21fdfb1a45c8aea&vjs=3', 'company': '코너스톤42', 'location': '서울 송파구'}
#
# {'position': 'AI 연구 MLOps의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=36ae5f764253d121&fccid=015d2bad6d9df969&vjs=3', 'company': '코그넷나인', 'location': '서울 서초구'}
#
# {'position': '파이썬(python) 백엔드 개발자 (전문연구요원 가능)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=240326a26bd13bf2&fccid=660bbb21789ab63d&vjs=3', 'company': '아토머스', 'location': '서울 강남구'}
#
# {'position': 'JR0192526 SW engineer intern의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83f4939522ffaa68&fccid=ded06d6a6799d929&vjs=3', 'company': '인텔코리아', 'location': '서울'}
#
# {'position': '리드급 풀스택 개발자 / 신입 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1fe6a772e758057c&fccid=89eb3eb174f006ff&vjs=3', 'company': '가보드림', 'location': '서울 서초구'}
#
# {'position': '[올라핀테크] 핀테크 플랫폼 Python(파이썬) 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=83afc0063130f3f2&fccid=ee9199e84b45d22f&vjs=3', 'company': '주식회사 올라핀테크 관심기업', 'location': '서울 논현동'}
#
# {'position': '(주)이젝스 연구소 소프트웨어 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=4e35249f02512af8&fccid=06535f1b49990e1a&vjs=3', 'company': '이젝스', 'location': '성남 중원구'}
#
# {'position': '[비에이코리아 주식회사] 데이터분석가(Business Data Analyst) 신입/경력의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=1dc91764525277cc&fccid=4c13ec332a36c73a&vjs=3', 'company': '비에이코리아', 'location': '서울'}
#
# {'position': '[배터리분야/인공지능개발] AI Developer를 모십니다.의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?cmp=(%EC%A3%BC)%EB%B0%94%EC%9D%B4%EC%98%A4%EC%97%90%EC%9D%B4%EC%95%84%EC%9D%B4&ti=%5B%EB%B0%B0%ED%84%B0%EB%A6%AC%EB%B6%84%EC%95%BC%2F%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5%EA%B0%9C%EB%B0%9C%5D+Ai+Developer%EB%A5%BC+%EB%AA%A8%EC%8B%AD%EB%8B%88%EB%8B%A4.&jk=159caf4673ba854e&fccid=2bf1cac26c8a5833&vjs=3', 'company': '(주)바이오에이아이', 'location': '서울'}
#
# {'position': '2023년 (주)하람아이 AI팀의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=f1a40936df480707&fccid=5d0ea4093a1ed598&vjs=3', 'company': '하람아이', 'location': '성남 수정구'}
#
# {'position': '[일반분야] (주)바이오에이아이 인공지능 데이터사이언티스트의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=c3af665e5f74fc55&fccid=9bfd5ec15f64fd72&vjs=3', 'company': '바이오에이아이', 'location': '서울 강남구'}
#
# {'position': '[선행기술원] 수치해석 기법 개발 (시뮬레이션)[책임연구원]의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=e88a012377584fab&fccid=980d6ecc399a3373&vjs=3', 'company': '현대자동차그룹', 'location': '성남 판교역'}
#
# {'position': 'Machine Learning Engineer Intern - Korea의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=69d3cc2cca262747&fccid=05089dbaca95e549&vjs=3', 'company': 'MOLOCO', 'location': '서울'}
#
# {'position': '2022년 상반기 주식회사 쏘마 전 개발 직군 (백엔드, 프론트엔드 외 신입/경력 정규직)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=13ef6f86810c0843&fccid=a3463f311ce6421e&vjs=3', 'company': '쏘마', 'location': '성남 분당구'}
#
# {'position': '[코어라인소프트] 3D 솔루션 개발자 찾습니다.의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=8abb8479693ab966&fccid=af283ee927a56dfc&vjs=3', 'company': '코어라인소프트', 'location': '서울 마포구'}
#
# {'position': '[HYBE] ITSM/CS의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=82477cde004f6386&fccid=55c46c15186153ee&vjs=3', 'company': '하이브', 'location': '서울 용산구'}

# %% [markdown]
# ---

# %% [markdown]
# - 완전 함수로 변환
#
# - return 리스트

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options


def extract_indeed_jobs(keyword):
    
    pages = get_page_count(keyword)
    
    results = []
  
    for page in range(pages):
        
        options = Options()

        browser = webdriver.Chrome(options=options)
        
        base_url = "https://kr.indeed.com/jobs"
        search_term = f'{keyword}'
        final_url = f"{base_url}?q={search_term}&start={page*10}"
        
        print(f'Request url : {final_url}')
        browser.get(final_url)

        # --- bs4 처리 

        soup = BeautifulSoup(browser.page_source, "html.parser")

        job_list = soup.find("ul", class_="jobsearch-ResultsList")

        jobs = job_list.find_all('li', recursive=False)


        # li 태그 중 class 네임에 따라 출력,
        # find, none 논리로 출력 


        for job in jobs:

            zone = job.find("div", class_="mosaic-zone")

            if zone == None:

                # anchor = job.find_all('a') # list

                anchor = job.select_one('h2 a') # dict

                title = anchor['aria-label']
                link = anchor['href']

                company = job.find('span', class_='companyName')
                location = job.find('div', class_='companyLocation')

                # dict 데이터 형
                job_data = {
                    'position': title,
                    'link': f"https://kr.indeed.com{link}",
                    'company': company.string,
                    'location': location.string
                }

                # 결과 리스트 append
                results.append(job_data)

    
    return results

# %%
# dict 데이터 형 job_data를 담고 있는 리스트 데이터 jobs


jobs = extract_indeed_jobs('python')

print(jobs)
# Out:
# Request url : https://kr.indeed.com/jobs?q=nest&start=0
# [{'position': '모빌리티엔 자동차보험 웹서비스 백엔드 개발자의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=f7920ae82f186b88&fccid=77914dd9da8d71f8&vjs=3', 'company': '모빌리티엔', 'location': '서울 성동구'}, {'position': 'Partner Manager, APAC의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=2e4aaa8f357f10c1&fccid=9ba9500ecf2596c5&vjs=3', 'company': 'Sendbird', 'location': '서울'}, {'position': '웹 서비스 및 모바일 앱의 UI 디자이너의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=ab91288ca5716c8b&fccid=550550f565ca2d67&vjs=3', 'company': '브레싱스 주식회사 관심기업', 'location': '서울 역삼동'}, {'position': 'CAD/ CAM 설계원 (신입 및 경력자 별도협의)의 전체 세부 정보', 'link': 'https://kr.indeed.com/rc/clk?jk=776425242e3dbbc9&fccid=6fcc48d21fceda12&vjs=3', 'company': '에스에이치엘', 'location': '대구 달성군'}]

# %%
print(len(jobs))
# Out:
# 4

# %% [markdown]
# - 첫번째 페이지로 이동후, 그 이후 페이지가 몇개 있는지 확인, 제약사항(5) 후 처리
